# %% [markdown]
# # NEURAL NETWORKS AND DEEP LEARNING
#
# ---
# A.A. 2021/22 (6 CFU) - Dr. Alberto Testolin, Dr. Umberto Michieli
# ---
#
#
# ## Lab. 03 - PyTorch regression and classification

# %%
import numpy as np
import matplotlib.pyplot as plt

import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader
from torchvision import transforms

# %%
import os
os.environ['CUDA_LAUNCH_BLOCKING'] = '1'

# %% [markdown]
# # Practical example: Linear Regression

# %% [markdown]
# Now let's solve the same problem analyzed in one of the previous lab using a simple neural network implemented in PyTorch.

# %% [markdown]
# # Data generation

# %% [markdown]
# Let's generate some data with our usual polynomial model, and save the data points in two csv files, one for training (train_data.csv), and one for validation (val_data.csv).
#
# You can find these files in the "Files" section of Colab. They are not stored in your local machine, but they are stored remotely in the Colab server.

# %%
def poly_model(x, beta, noise_std=0):
    """
    INPUT
        x: x vector
        beta: polynomial parameters
        noise_std: enable noisy sampling (gaussian noise, zero mean, noise_std std)
    """
    pol_order = len(beta)
    x_matrix = np.array([x**i for i in range(pol_order)]).transpose()
    y = np.matmul(x_matrix, beta)
    noise = np.random.randn(len(y)) * noise_std
    return y + noise

beta_true = [-1.45, 1.12, 2.3]
noise_std = 0.2
np.random.seed(4)

### Train data
num_train_points = 20
x_train = np.random.rand(num_train_points)
y_train = poly_model(x_train, beta_true, noise_std)
with open('train_data.csv', 'w') as f:
    data = [f"{x},{y}" for x, y in zip(x_train, y_train)]
    f.write('\n'.join(data))
    
### Validation data
num_val_points = 20
x_val = np.random.rand(num_val_points)
y_val = poly_model(x_val, beta_true, noise_std)
with open('val_data.csv', 'w') as f:
    data = [f"{x},{y}" for x, y in zip(x_val, y_val)]
    f.write('\n'.join(data))


### Plot
plt.figure(figsize=(12,8))
x_highres = np.linspace(0,1,1000)
plt.plot(x_highres, poly_model(x_highres, beta_true), color='b', ls='--', label='True data model')
plt.plot(x_train, y_train, color='r', ls='', marker='.', label='Train data points')
plt.plot(x_val, y_val, color='g', ls='', marker='.', label='Validation data points')
plt.xlabel('x')
plt.ylabel('y')
plt.grid()
plt.legend()
plt.tight_layout()
plt.show()

# %% [markdown]
# # Network Training

# %% [markdown]
# ## Network Definition

# %% [markdown]
# Define a fully connected feed-forward network with 2 hidden layers.
#
# Use a sigmoid activation function.
#
# Since this is a regression, we do not want to limit the value of the output. For this reason, NO activation function should be used for the output layer.

# %%
class Net(nn.Module):
    
    def __init__(self, Ni, Nh1, Nh2, No):
        """
        Ni - Input size
        Nh1 - Neurons in the 1st hidden layer
        Nh2 - Neurons in the 2nd hidden layer
        No - Output size
        """
        super().__init__()
        
        print('Network initialized')
        self.fc1 = nn.Linear(in_features=Ni, out_features=Nh1)
        self.fc2 = nn.Linear(in_features=Nh1, out_features=Nh2)
        self.out = nn.Linear(in_features=Nh2, out_features=No)
        self.act = nn.Sigmoid()
        
    def forward(self, x, additional_out=False):
        x = self.act(self.fc1(x)) #don't forget activation: not included by default 
        x = self.act(self.fc2(x))
        x = self.out(x)
        return x

# %% [markdown]
# ## Dataset and Dataloader

# %% [markdown]
# We have already implemented the dataset class in the previous lab.

# %% [markdown]
# ### Dataset

# %%
class CsvDataset(Dataset):

    def __init__(self, csv_file, transform=None):
        """
        Args:
            csv_file (string): Path to the csv file.
            transform (callable, optional): Optional transform to be applied
                on a sample.
        """
        self.transform = transform
        # Read the file and split the lines in a list
        with open(csv_file, 'r') as f:
            lines = f.read().split('\n')
        # Get x and y values from each line and append to self.data
        self.data = []
        for line in lines:
            sample = line.split(',')
            self.data.append((float(sample[0]), float(sample[1])))
        # Now self.data contains all our dataset.
        # Each element of the list self.data is a tuple: (input, output)

    def __len__(self):
        # The length of the dataset is simply the length of the self.data list
        return len(self.data)

    def __getitem__(self, idx):
        # Our sample is the element idx of the list self.data
        sample = self.data[idx]
        if self.transform:
            sample = self.transform(sample)
        return sample

# %% [markdown]
# ### Transforms

# %%
class ToTensor(object):
    """Convert sample to Tensors."""

    def __call__(self, sample):
        x, y = sample
        return (torch.tensor([x]).float(),
                torch.tensor([y]).float())

# %%
composed_transform = transforms.Compose([ToTensor()])

train_dataset = CsvDataset('train_data.csv', transform=composed_transform)
val_dataset = CsvDataset('val_data.csv', transform=composed_transform)

# %% [markdown]
# ### Dataloader

# %% [markdown]
# For the dataloader:
#
# * enable the shuffling only for training data
# * try different values for batch size
# * disable the multiprocessing

# %%
train_dataloader = DataLoader(train_dataset, batch_size=4, shuffle=True, num_workers=0)
val_dataloader  = DataLoader(val_dataset,  batch_size=len(val_dataset), shuffle=False, num_workers=0)

#val divided in batch only if it doesn't fit in memory, not using in this case, also we do not shuffle the validation

# %% [markdown]
# ## Training loop

# %% [markdown]
# Now we put together all the steps analyzed in the previous lab:

# %%
# Check if the GPU is available
device = torch.device("cuda") if torch.cuda.is_available() else torch.device("cpu")
print(f"Training device: {device}")
# Out:
# Training device: cuda

# %%
# Initialize the network
torch.manual_seed(0)
Ni = 1
Nh1 = 128
Nh2 = 256
No = 1
net = Net(Ni, Nh1, Nh2, No)
net.to(device)
# Out:
# Network initialized
# Net(
#   (fc1): Linear(in_features=1, out_features=128, bias=True)
#   (fc2): Linear(in_features=128, out_features=256, bias=True)
#   (out): Linear(in_features=256, out_features=1, bias=True)
#   (act): Sigmoid()
# )

# %%
# Define the loss function
loss_fn = nn.MSELoss()

# %%
# Define the optimizer
optimizer = optim.Adam(net.parameters(), lr=1e-3)

# %%
### TRAINING LOOP

#SG run some epochs over the data, to do this a just a for loop, inside we loop over the batches. 
#Here the network must be in training mode.

num_epochs = 3000
train_loss_log = []
val_loss_log = []
for epoch_num in range(num_epochs):
    print('#################')
    print(f'# EPOCH {epoch_num}')
    print('#################')

    ### TRAIN
    train_loss= []
    net.train() # Training mode (e.g. enable dropout, batchnorm updates,...)
    for sample_batched in train_dataloader:
        # Move data to device
        x_batch = sample_batched[0].to(device)
        label_batch = sample_batched[1].to(device)

        # Forward pass
        out = net(x_batch)

        # Compute loss
        loss = loss_fn(out, label_batch)

        # Backpropagation
        net.zero_grad() #set all the gradient to zero
        loss.backward() #call the backward func.

        # Update the weights
        optimizer.step()

        # Save train loss for this batch
        loss_batch = loss.detach().cpu().numpy()
        train_loss.append(loss_batch)

    # Save average train loss
    train_loss = np.mean(train_loss)
    print(f"AVERAGE TRAIN LOSS: {train_loss}")
    train_loss_log.append(train_loss)

    ### VALIDATION
    val_loss= []
    #Set network in evaluation mode, parameters are frozd, in this case we do the 
    #validation after every step of the training
    
    net.eval() # Evaluation mode (e.g. disable dropout, batchnorm,...)
    with torch.no_grad(): # Disable gradient tracking
        for sample_batched in val_dataloader:
            # Move data to device
            x_batch = sample_batched[0].to(device)
            label_batch = sample_batched[1].to(device)

            # Forward pass
            out = net(x_batch)

            # Compute loss
            loss = loss_fn(out, label_batch)

            # Save val loss for this batch
            loss_batch = loss.detach().cpu().numpy()
            val_loss.append(loss_batch)

        # Save average validation loss
        val_loss = np.mean(val_loss)
        print(f"AVERAGE VAL LOSS: {np.mean(val_loss)}")
        val_loss_log.append(val_loss)
# Out:
# Streaming output truncated to the last 5000 lines.
# #################
# # EPOCH 2000
# #################
# AVERAGE TRAIN LOSS: 0.030761176720261574
# AVERAGE VAL LOSS: 0.07925938814878464
# #################
# # EPOCH 2001
# #################
# AVERAGE TRAIN LOSS: 0.023854685947299004
# AVERAGE VAL LOSS: 0.056820254772901535
# #################
# # EPOCH 2002
# #################
# AVERAGE TRAIN LOSS: 0.023417340591549873
# AVERAGE VAL LOSS: 0.060226358473300934
# #################
# # EPOCH 2003
# #################
# AVERAGE TRAIN LOSS: 0.02044099010527134
# AVERAGE VAL LOSS: 0.06732535362243652
# #################
# # EPOCH 2004
# #################
# AVERAGE TRAIN LOSS: 0.02026502601802349
# AVERAGE VAL LOSS: 0.05813707783818245
# #################
# # EPOCH 2005
# #################
# AVERAGE TRAIN LOSS: 0.01976548135280609
# AVERAGE VAL LOSS: 0.05999647453427315
# #################
# # EPOCH 2006
# #################
# AVERAGE TRAIN LOSS: 0.020112361758947372
# AVERAGE VAL LOSS: 0.06144241243600845
# #################
# # EPOCH 2007
# #################
# AVERAGE TRAIN LOSS: 0.019653435796499252
# AVERAGE VAL LOSS: 0.060180045664310455
# #################
# # EPOCH 2008
# #################
# AVERAGE TRAIN LOSS: 0.019838476553559303
# AVERAGE VAL LOSS: 0.05899708345532417
# #################
# # EPOCH 2009
# #################
# AVERAGE TRAIN LOSS: 0.019582495093345642
# AVERAGE VAL LOSS: 0.06403426080942154
# #################
# # EPOCH 2010
# #################
# AVERAGE TRAIN LOSS: 0.021391896530985832
# AVERAGE VAL LOSS: 0.061103880405426025
# #################
# # EPOCH 2011
# #################
# AVERAGE TRAIN LOSS: 0.027714664116501808
# AVERAGE VAL LOSS: 0.05644984170794487
# #################
# # EPOCH 2012
# #################
# AVERAGE TRAIN LOSS: 0.021354258060455322
# AVERAGE VAL LOSS: 0.07433729618787766
# #################
# # EPOCH 2013
# #################
# AVERAGE TRAIN LOSS: 0.023614082485437393
# AVERAGE VAL LOSS: 0.06252351403236389
# #################
# # EPOCH 2014
# #################
# AVERAGE TRAIN LOSS: 0.026787733659148216
# AVERAGE VAL LOSS: 0.05863240361213684
# #################
# # EPOCH 2015
# #################
# AVERAGE TRAIN LOSS: 0.025500675663352013
# AVERAGE VAL LOSS: 0.0729912742972374
# #################
# # EPOCH 2016
# #################
# AVERAGE TRAIN LOSS: 0.024006536230444908
# AVERAGE VAL LOSS: 0.058808159083127975
# #################
# # EPOCH 2017
# #################
# AVERAGE TRAIN LOSS: 0.020000101998448372
# AVERAGE VAL LOSS: 0.06126558780670166
# #################
# # EPOCH 2018
# #################
# AVERAGE TRAIN LOSS: 0.019539358094334602
# AVERAGE VAL LOSS: 0.06132016330957413
# #################
# # EPOCH 2019
# #################
# AVERAGE TRAIN LOSS: 0.021306443959474564
# AVERAGE VAL LOSS: 0.05896406248211861
# #################
# # EPOCH 2020
# #################
# AVERAGE TRAIN LOSS: 0.019054904580116272
# AVERAGE VAL LOSS: 0.0623106025159359
# #################
# # EPOCH 2021
# #################
# AVERAGE TRAIN LOSS: 0.01991172693669796
# AVERAGE VAL LOSS: 0.062404561787843704
# #################
# # EPOCH 2022
# #################
# AVERAGE TRAIN LOSS: 0.02052200958132744
# AVERAGE VAL LOSS: 0.05934910848736763
# #################
# # EPOCH 2023
# #################
# AVERAGE TRAIN LOSS: 0.021598976105451584
# AVERAGE VAL LOSS: 0.06071779876947403
# #################
# # EPOCH 2024
# #################
# AVERAGE TRAIN LOSS: 0.02372908778488636
# AVERAGE VAL LOSS: 0.0704159140586853
# #################
# # EPOCH 2025
# #################
# AVERAGE TRAIN LOSS: 0.01964426413178444
# AVERAGE VAL LOSS: 0.05614130571484566
# #################
# # EPOCH 2026
# #################
# AVERAGE TRAIN LOSS: 0.02375827170908451
# AVERAGE VAL LOSS: 0.05757435783743858
# #################
# # EPOCH 2027
# #################
# AVERAGE TRAIN LOSS: 0.020679881796240807
# AVERAGE VAL LOSS: 0.07058236747980118
# #################
# # EPOCH 2028
# #################
# AVERAGE TRAIN LOSS: 0.02250247448682785
# AVERAGE VAL LOSS: 0.06281929463148117
# #################
# # EPOCH 2029
# #################
# AVERAGE TRAIN LOSS: 0.01908125914633274
# AVERAGE VAL LOSS: 0.057730671018362045
# #################
# # EPOCH 2030
# #################
# AVERAGE TRAIN LOSS: 0.020618861541152
# AVERAGE VAL LOSS: 0.06094575673341751
# #################
# # EPOCH 2031
# #################
# AVERAGE TRAIN LOSS: 0.02015683427453041
# AVERAGE VAL LOSS: 0.07038858532905579
# #################
# # EPOCH 2032
# #################
# AVERAGE TRAIN LOSS: 0.020652540028095245
# AVERAGE VAL LOSS: 0.059011053293943405
# #################
# # EPOCH 2033
# #################
# AVERAGE TRAIN LOSS: 0.019958538934588432
# AVERAGE VAL LOSS: 0.059751249849796295
# #################
# # EPOCH 2034
# #################
# AVERAGE TRAIN LOSS: 0.01911875605583191
# AVERAGE VAL LOSS: 0.06112397462129593
# #################
# # EPOCH 2035
# #################
# AVERAGE TRAIN LOSS: 0.02041875198483467
# AVERAGE VAL LOSS: 0.06588654965162277
# #################
# # EPOCH 2036
# #################
# AVERAGE TRAIN LOSS: 0.020058616995811462
# AVERAGE VAL LOSS: 0.059304576367139816
# #################
# # EPOCH 2037
# #################
# AVERAGE TRAIN LOSS: 0.021235281601548195
# AVERAGE VAL LOSS: 0.06057051569223404
# #################
# # EPOCH 2038
# #################
# AVERAGE TRAIN LOSS: 0.01906636357307434
# AVERAGE VAL LOSS: 0.0664534643292427
# #################
# # EPOCH 2039
# #################
# AVERAGE TRAIN LOSS: 0.019533950835466385
# AVERAGE VAL LOSS: 0.06031975895166397
# #################
# # EPOCH 2040
# #################
# AVERAGE TRAIN LOSS: 0.02137010544538498
# AVERAGE VAL LOSS: 0.05714981630444527
# #################
# # EPOCH 2041
# #################
# AVERAGE TRAIN LOSS: 0.01826050877571106
# AVERAGE VAL LOSS: 0.06435669958591461
# #################
# # EPOCH 2042
# #################
# AVERAGE TRAIN LOSS: 0.019863981753587723
# AVERAGE VAL LOSS: 0.06366214156150818
# #################
# # EPOCH 2043
# #################
# AVERAGE TRAIN LOSS: 0.019083809107542038
# AVERAGE VAL LOSS: 0.060714252293109894
# #################
# # EPOCH 2044
# #################
# AVERAGE TRAIN LOSS: 0.01956857368350029
# AVERAGE VAL LOSS: 0.05967557057738304
# #################
# # EPOCH 2045
# #################
# AVERAGE TRAIN LOSS: 0.018881749361753464
# AVERAGE VAL LOSS: 0.06252483278512955
# #################
# # EPOCH 2046
# #################
# AVERAGE TRAIN LOSS: 0.019670141860842705
# AVERAGE VAL LOSS: 0.06530775874853134
# #################
# # EPOCH 2047
# #################
# AVERAGE TRAIN LOSS: 0.021189669147133827
# AVERAGE VAL LOSS: 0.05958638712763786
# #################
# # EPOCH 2048
# #################
# AVERAGE TRAIN LOSS: 0.020806115120649338
# AVERAGE VAL LOSS: 0.05967053771018982
# #################
# # EPOCH 2049
# #################
# AVERAGE TRAIN LOSS: 0.025583410635590553
# AVERAGE VAL LOSS: 0.05787548050284386
# #################
# # EPOCH 2050
# #################
# AVERAGE TRAIN LOSS: 0.024506712332367897
# AVERAGE VAL LOSS: 0.07726234197616577
# #################
# # EPOCH 2051
# #################
# AVERAGE TRAIN LOSS: 0.021185729652643204
# AVERAGE VAL LOSS: 0.058528948575258255
# #################
# # EPOCH 2052
# #################
# AVERAGE TRAIN LOSS: 0.0214221328496933
# AVERAGE VAL LOSS: 0.05731458589434624
# #################
# # EPOCH 2053
# #################
# AVERAGE TRAIN LOSS: 0.021219829097390175
# AVERAGE VAL LOSS: 0.06668847054243088
# #################
# # EPOCH 2054
# #################
# AVERAGE TRAIN LOSS: 0.01972263678908348
# AVERAGE VAL LOSS: 0.06243252754211426
# #################
# # EPOCH 2055
# #################
# AVERAGE TRAIN LOSS: 0.01921161636710167
# AVERAGE VAL LOSS: 0.05860552936792374
# #################
# # EPOCH 2056
# #################
# AVERAGE TRAIN LOSS: 0.020188305526971817
# AVERAGE VAL LOSS: 0.06297506392002106
# #################
# # EPOCH 2057
# #################
# AVERAGE TRAIN LOSS: 0.019286692142486572
# AVERAGE VAL LOSS: 0.0629398450255394
# #################
# # EPOCH 2058
# #################
# AVERAGE TRAIN LOSS: 0.019677137956023216
# AVERAGE VAL LOSS: 0.06074165180325508
# #################
# # EPOCH 2059
# #################
# AVERAGE TRAIN LOSS: 0.019895024597644806
# AVERAGE VAL LOSS: 0.06518816947937012
# #################
# # EPOCH 2060
# #################
# AVERAGE TRAIN LOSS: 0.0198055449873209
# AVERAGE VAL LOSS: 0.060494374483823776
# #################
# # EPOCH 2061
# #################
# AVERAGE TRAIN LOSS: 0.024819303303956985
# AVERAGE VAL LOSS: 0.06397562474012375
# #################
# # EPOCH 2062
# #################
# AVERAGE TRAIN LOSS: 0.02077307738363743
# AVERAGE VAL LOSS: 0.05871939659118652
# #################
# # EPOCH 2063
# #################
# AVERAGE TRAIN LOSS: 0.020123690366744995
# AVERAGE VAL LOSS: 0.057683300226926804
# #################
# # EPOCH 2064
# #################
# AVERAGE TRAIN LOSS: 0.024025510996580124
# AVERAGE VAL LOSS: 0.06819929927587509
# #################
# # EPOCH 2065
# #################
# AVERAGE TRAIN LOSS: 0.02105504460632801
# AVERAGE VAL LOSS: 0.060987718403339386
# #################
# # EPOCH 2066
# #################
# AVERAGE TRAIN LOSS: 0.019531290978193283
# AVERAGE VAL LOSS: 0.061580538749694824
# #################
# # EPOCH 2067
# #################
# AVERAGE TRAIN LOSS: 0.02003234252333641
# AVERAGE VAL LOSS: 0.06312020123004913
# #################
# # EPOCH 2068
# #################
# AVERAGE TRAIN LOSS: 0.02029292657971382
# AVERAGE VAL LOSS: 0.06034884601831436
# #################
# # EPOCH 2069
# #################
# AVERAGE TRAIN LOSS: 0.019232500344514847
# AVERAGE VAL LOSS: 0.06049147993326187
# #################
# # EPOCH 2070
# #################
# AVERAGE TRAIN LOSS: 0.019224394112825394
# AVERAGE VAL LOSS: 0.06100798770785332
# #################
# # EPOCH 2071
# #################
# AVERAGE TRAIN LOSS: 0.0205801073461771
# AVERAGE VAL LOSS: 0.06483539938926697
# #################
# # EPOCH 2072
# #################
# AVERAGE TRAIN LOSS: 0.019978027790784836
# AVERAGE VAL LOSS: 0.05880878120660782
# #################
# # EPOCH 2073
# #################
# AVERAGE TRAIN LOSS: 0.022511092945933342
# AVERAGE VAL LOSS: 0.06430502235889435
# #################
# # EPOCH 2074
# #################
# AVERAGE TRAIN LOSS: 0.02008732222020626
# AVERAGE VAL LOSS: 0.06005214527249336
# #################
# # EPOCH 2075
# #################
# AVERAGE TRAIN LOSS: 0.019798725843429565
# AVERAGE VAL LOSS: 0.06235251575708389
# #################
# # EPOCH 2076
# #################
# AVERAGE TRAIN LOSS: 0.020048197358846664
# AVERAGE VAL LOSS: 0.05889797955751419
# #################
# # EPOCH 2077
# #################
# AVERAGE TRAIN LOSS: 0.020624391734600067
# AVERAGE VAL LOSS: 0.0637502521276474
# #################
# # EPOCH 2078
# #################
# AVERAGE TRAIN LOSS: 0.020540952682495117
# AVERAGE VAL LOSS: 0.06056266650557518
# #################
# # EPOCH 2079
# #################
# AVERAGE TRAIN LOSS: 0.02011677622795105
# AVERAGE VAL LOSS: 0.06020671874284744
# #################
# # EPOCH 2080
# #################
# AVERAGE TRAIN LOSS: 0.02013610675930977
# AVERAGE VAL LOSS: 0.06317146867513657
# #################
# # EPOCH 2081
# #################
# AVERAGE TRAIN LOSS: 0.019488193094730377
# AVERAGE VAL LOSS: 0.06008686497807503
# #################
# # EPOCH 2082
# #################
# AVERAGE TRAIN LOSS: 0.022868745028972626
# AVERAGE VAL LOSS: 0.06016135960817337
# #################
# # EPOCH 2083
# #################
# AVERAGE TRAIN LOSS: 0.019153762608766556
# AVERAGE VAL LOSS: 0.07063908874988556
# #################
# # EPOCH 2084
# #################
# AVERAGE TRAIN LOSS: 0.021946776658296585
# AVERAGE VAL LOSS: 0.06207820400595665
# #################
# # EPOCH 2085
# #################
# AVERAGE TRAIN LOSS: 0.02367793582379818
# AVERAGE VAL LOSS: 0.05870072916150093
# #################
# # EPOCH 2086
# #################
# AVERAGE TRAIN LOSS: 0.018991801887750626
# AVERAGE VAL LOSS: 0.06659308820962906
# #################
# # EPOCH 2087
# #################
# AVERAGE TRAIN LOSS: 0.02554546855390072
# AVERAGE VAL LOSS: 0.06644055992364883
# #################
# # EPOCH 2088
# #################
# AVERAGE TRAIN LOSS: 0.02624983713030815
# AVERAGE VAL LOSS: 0.05764171481132507
# #################
# # EPOCH 2089
# #################
# AVERAGE TRAIN LOSS: 0.024481605738401413
# AVERAGE VAL LOSS: 0.0717351958155632
# #################
# # EPOCH 2090
# #################
# AVERAGE TRAIN LOSS: 0.025725629180669785
# AVERAGE VAL LOSS: 0.06347974389791489
# #################
# # EPOCH 2091
# #################
# AVERAGE TRAIN LOSS: 0.01969389244914055
# AVERAGE VAL LOSS: 0.059440165758132935
# #################
# # EPOCH 2092
# #################
# AVERAGE TRAIN LOSS: 0.021553419530391693
# AVERAGE VAL LOSS: 0.061367638409137726
# #################
# # EPOCH 2093
# #################
# AVERAGE TRAIN LOSS: 0.02400352992117405
# AVERAGE VAL LOSS: 0.07217562198638916
# #################
# # EPOCH 2094
# #################
# AVERAGE TRAIN LOSS: 0.021435631439089775
# AVERAGE VAL LOSS: 0.05913562700152397
# #################
# # EPOCH 2095
# #################
# AVERAGE TRAIN LOSS: 0.020204830914735794
# AVERAGE VAL LOSS: 0.05820344761013985
# #################
# # EPOCH 2096
# #################
# AVERAGE TRAIN LOSS: 0.020390141755342484
# AVERAGE VAL LOSS: 0.062163639813661575
# #################
# # EPOCH 2097
# #################
# AVERAGE TRAIN LOSS: 0.020771775394678116
# AVERAGE VAL LOSS: 0.058949023485183716
# #################
# # EPOCH 2098
# #################
# AVERAGE TRAIN LOSS: 0.02105247601866722
# AVERAGE VAL LOSS: 0.06334348022937775
# #################
# # EPOCH 2099
# #################
# AVERAGE TRAIN LOSS: 0.0203253086656332
# AVERAGE VAL LOSS: 0.056605931371450424
# #################
# # EPOCH 2100
# #################
# AVERAGE TRAIN LOSS: 0.020058725029230118
# AVERAGE VAL LOSS: 0.05958189442753792
# #################
# # EPOCH 2101
# #################
# AVERAGE TRAIN LOSS: 0.021733403205871582
# AVERAGE VAL LOSS: 0.06733734160661697
# #################
# # EPOCH 2102
# #################
# AVERAGE TRAIN LOSS: 0.019812870770692825
# AVERAGE VAL LOSS: 0.05999547988176346
# #################
# # EPOCH 2103
# #################
# AVERAGE TRAIN LOSS: 0.02246415987610817
# AVERAGE VAL LOSS: 0.05800405889749527
# #################
# # EPOCH 2104
# #################
# AVERAGE TRAIN LOSS: 0.019878897815942764
# AVERAGE VAL LOSS: 0.06554428488016129
# #################
# # EPOCH 2105
# #################
# AVERAGE TRAIN LOSS: 0.02077128365635872
# AVERAGE VAL LOSS: 0.06222015619277954
# #################
# # EPOCH 2106
# #################
# AVERAGE TRAIN LOSS: 0.02272700145840645
# AVERAGE VAL LOSS: 0.05587325617671013
# #################
# # EPOCH 2107
# #################
# AVERAGE TRAIN LOSS: 0.022362634539604187
# AVERAGE VAL LOSS: 0.06580988317728043
# #################
# # EPOCH 2108
# #################
# AVERAGE TRAIN LOSS: 0.02003813348710537
# AVERAGE VAL LOSS: 0.059100162237882614
# #################
# # EPOCH 2109
# #################
# AVERAGE TRAIN LOSS: 0.019469209015369415
# AVERAGE VAL LOSS: 0.05939318612217903
# #################
# # EPOCH 2110
# #################
# AVERAGE TRAIN LOSS: 0.019668344408273697
# AVERAGE VAL LOSS: 0.06175187975168228
# #################
# # EPOCH 2111
# #################
# AVERAGE TRAIN LOSS: 0.02021675370633602
# AVERAGE VAL LOSS: 0.05884972959756851
# #################
# # EPOCH 2112
# #################
# AVERAGE TRAIN LOSS: 0.01968352310359478
# AVERAGE VAL LOSS: 0.06273073703050613
# #################
# # EPOCH 2113
# #################
# AVERAGE TRAIN LOSS: 0.02254643104970455
# AVERAGE VAL LOSS: 0.07172051817178726
# #################
# # EPOCH 2114
# #################
# AVERAGE TRAIN LOSS: 0.022034786641597748
# AVERAGE VAL LOSS: 0.05881214886903763
# #################
# # EPOCH 2115
# #################
# AVERAGE TRAIN LOSS: 0.020078817382454872
# AVERAGE VAL LOSS: 0.061412960290908813
# #################
# # EPOCH 2116
# #################
# AVERAGE TRAIN LOSS: 0.019043192267417908
# AVERAGE VAL LOSS: 0.06448809802532196
# #################
# # EPOCH 2117
# #################
# AVERAGE TRAIN LOSS: 0.01970325969159603
# AVERAGE VAL LOSS: 0.06089222431182861
# #################
# # EPOCH 2118
# #################
# AVERAGE TRAIN LOSS: 0.021259333938360214
# AVERAGE VAL LOSS: 0.05848090723156929
# #################
# # EPOCH 2119
# #################
# AVERAGE TRAIN LOSS: 0.020901944488286972
# AVERAGE VAL LOSS: 0.06374480575323105
# #################
# # EPOCH 2120
# #################
# AVERAGE TRAIN LOSS: 0.022125715389847755
# AVERAGE VAL LOSS: 0.058783747255802155
# #################
# # EPOCH 2121
# #################
# AVERAGE TRAIN LOSS: 0.019426191225647926
# AVERAGE VAL LOSS: 0.060946524143218994
# #################
# # EPOCH 2122
# #################
# AVERAGE TRAIN LOSS: 0.02080206386744976
# AVERAGE VAL LOSS: 0.06909819692373276
# #################
# # EPOCH 2123
# #################
# AVERAGE TRAIN LOSS: 0.01945139653980732
# AVERAGE VAL LOSS: 0.0594305694103241
# #################
# # EPOCH 2124
# #################
# AVERAGE TRAIN LOSS: 0.019842039793729782
# AVERAGE VAL LOSS: 0.06050657108426094
# #################
# # EPOCH 2125
# #################
# AVERAGE TRAIN LOSS: 0.019105104729533195
# AVERAGE VAL LOSS: 0.06115800142288208
# #################
# # EPOCH 2126
# #################
# AVERAGE TRAIN LOSS: 0.020268578082323074
# AVERAGE VAL LOSS: 0.06477508693933487
# #################
# # EPOCH 2127
# #################
# AVERAGE TRAIN LOSS: 0.02043900638818741
# AVERAGE VAL LOSS: 0.05933398753404617
# #################
# # EPOCH 2128
# #################
# AVERAGE TRAIN LOSS: 0.02050277404487133
# AVERAGE VAL LOSS: 0.06365566700696945
# #################
# # EPOCH 2129
# #################
# AVERAGE TRAIN LOSS: 0.019070083275437355
# AVERAGE VAL LOSS: 0.06090039014816284
# #################
# # EPOCH 2130
# #################
# AVERAGE TRAIN LOSS: 0.02067457139492035
# AVERAGE VAL LOSS: 0.05650104954838753
# #################
# # EPOCH 2131
# #################
# AVERAGE TRAIN LOSS: 0.021273156628012657
# AVERAGE VAL LOSS: 0.06604607403278351
# #################
# # EPOCH 2132
# #################
# AVERAGE TRAIN LOSS: 0.020925436168909073
# AVERAGE VAL LOSS: 0.06116437911987305
# #################
# # EPOCH 2133
# #################
# AVERAGE TRAIN LOSS: 0.02270258404314518
# AVERAGE VAL LOSS: 0.0571405403316021
# #################
# # EPOCH 2134
# #################
# AVERAGE TRAIN LOSS: 0.018729334697127342
# AVERAGE VAL LOSS: 0.06357162445783615
# #################
# # EPOCH 2135
# #################
# AVERAGE TRAIN LOSS: 0.02313421666622162
# AVERAGE VAL LOSS: 0.07400113344192505
# #################
# # EPOCH 2136
# #################
# AVERAGE TRAIN LOSS: 0.019085733219981194
# AVERAGE VAL LOSS: 0.060194291174411774
# #################
# # EPOCH 2137
# #################
# AVERAGE TRAIN LOSS: 0.022120006382465363
# AVERAGE VAL LOSS: 0.05856277421116829
# #################
# # EPOCH 2138
# #################
# AVERAGE TRAIN LOSS: 0.021404853090643883
# AVERAGE VAL LOSS: 0.06738050282001495
# #################
# # EPOCH 2139
# #################
# AVERAGE TRAIN LOSS: 0.020422985777258873
# AVERAGE VAL LOSS: 0.05910559371113777
# #################
# # EPOCH 2140
# #################
# AVERAGE TRAIN LOSS: 0.020773818716406822
# AVERAGE VAL LOSS: 0.058648109436035156
# #################
# # EPOCH 2141
# #################
# AVERAGE TRAIN LOSS: 0.023149825632572174
# AVERAGE VAL LOSS: 0.07047345489263535
# #################
# # EPOCH 2142
# #################
# AVERAGE TRAIN LOSS: 0.01990630105137825
# AVERAGE VAL LOSS: 0.062211114913225174
# #################
# # EPOCH 2143
# #################
# AVERAGE TRAIN LOSS: 0.02253054454922676
# AVERAGE VAL LOSS: 0.059955012053251266
# #################
# # EPOCH 2144
# #################
# AVERAGE TRAIN LOSS: 0.02219662442803383
# AVERAGE VAL LOSS: 0.07139822095632553
# #################
# # EPOCH 2145
# #################
# AVERAGE TRAIN LOSS: 0.020560383796691895
# AVERAGE VAL LOSS: 0.061583708971738815
# #################
# # EPOCH 2146
# #################
# AVERAGE TRAIN LOSS: 0.023514043539762497
# AVERAGE VAL LOSS: 0.05636395886540413
# #################
# # EPOCH 2147
# #################
# AVERAGE TRAIN LOSS: 0.019772563129663467
# AVERAGE VAL LOSS: 0.0695631206035614
# #################
# # EPOCH 2148
# #################
# AVERAGE TRAIN LOSS: 0.02680937573313713
# AVERAGE VAL LOSS: 0.06920690089464188
# #################
# # EPOCH 2149
# #################
# AVERAGE TRAIN LOSS: 0.01940668560564518
# AVERAGE VAL LOSS: 0.06126835569739342
# #################
# # EPOCH 2150
# #################
# AVERAGE TRAIN LOSS: 0.02404075488448143
# AVERAGE VAL LOSS: 0.05901200696825981
# #################
# # EPOCH 2151
# #################
# AVERAGE TRAIN LOSS: 0.01646009273827076
# AVERAGE VAL LOSS: 0.06891018152236938
# #################
# # EPOCH 2152
# #################
# AVERAGE TRAIN LOSS: 0.0259882602840662
# AVERAGE VAL LOSS: 0.0692334845662117
# #################
# # EPOCH 2153
# #################
# AVERAGE TRAIN LOSS: 0.029043350368738174
# AVERAGE VAL LOSS: 0.05615433678030968
# #################
# # EPOCH 2154
# #################
# AVERAGE TRAIN LOSS: 0.020873021334409714
# AVERAGE VAL LOSS: 0.06493087857961655
# #################
# # EPOCH 2155
# #################
# AVERAGE TRAIN LOSS: 0.023394165560603142
# AVERAGE VAL LOSS: 0.07004868239164352
# #################
# # EPOCH 2156
# #################
# AVERAGE TRAIN LOSS: 0.023614447563886642
# AVERAGE VAL LOSS: 0.05782810598611832
# #################
# # EPOCH 2157
# #################
# AVERAGE TRAIN LOSS: 0.020277250558137894
# AVERAGE VAL LOSS: 0.0600188747048378
# #################
# # EPOCH 2158
# #################
# AVERAGE TRAIN LOSS: 0.021033387631177902
# AVERAGE VAL LOSS: 0.06609203666448593
# #################
# # EPOCH 2159
# #################
# AVERAGE TRAIN LOSS: 0.021858548745512962
# AVERAGE VAL LOSS: 0.057971514761447906
# #################
# # EPOCH 2160
# #################
# AVERAGE TRAIN LOSS: 0.01949525624513626
# AVERAGE VAL LOSS: 0.060276854783296585
# #################
# # EPOCH 2161
# #################
# AVERAGE TRAIN LOSS: 0.019536659121513367
# AVERAGE VAL LOSS: 0.06438612192869186
# #################
# # EPOCH 2162
# #################
# AVERAGE TRAIN LOSS: 0.018924793228507042
# AVERAGE VAL LOSS: 0.06001909449696541
# #################
# # EPOCH 2163
# #################
# AVERAGE TRAIN LOSS: 0.01948983035981655
# AVERAGE VAL LOSS: 0.06095234304666519
# #################
# # EPOCH 2164
# #################
# AVERAGE TRAIN LOSS: 0.019085338339209557
# AVERAGE VAL LOSS: 0.06222944334149361
# #################
# # EPOCH 2165
# #################
# AVERAGE TRAIN LOSS: 0.019733447581529617
# AVERAGE VAL LOSS: 0.06134864315390587
# #################
# # EPOCH 2166
# #################
# AVERAGE TRAIN LOSS: 0.02125163935124874
# AVERAGE VAL LOSS: 0.06651865690946579
# #################
# # EPOCH 2167
# #################
# AVERAGE TRAIN LOSS: 0.01973426528275013
# AVERAGE VAL LOSS: 0.057986050844192505
# #################
# # EPOCH 2168
# #################
# AVERAGE TRAIN LOSS: 0.022353556007146835
# AVERAGE VAL LOSS: 0.06139663979411125
# #################
# # EPOCH 2169
# #################
# AVERAGE TRAIN LOSS: 0.021934732794761658
# AVERAGE VAL LOSS: 0.06300819665193558
# #################
# # EPOCH 2170
# #################
# AVERAGE TRAIN LOSS: 0.018550820648670197
# AVERAGE VAL LOSS: 0.05944123491644859
# #################
# # EPOCH 2171
# #################
# AVERAGE TRAIN LOSS: 0.0244101881980896
# AVERAGE VAL LOSS: 0.05746227130293846
# #################
# # EPOCH 2172
# #################
# AVERAGE TRAIN LOSS: 0.02025672420859337
# AVERAGE VAL LOSS: 0.07072856277227402
# #################
# # EPOCH 2173
# #################
# AVERAGE TRAIN LOSS: 0.024763714522123337
# AVERAGE VAL LOSS: 0.06685727834701538
# #################
# # EPOCH 2174
# #################
# AVERAGE TRAIN LOSS: 0.01801368035376072
# AVERAGE VAL LOSS: 0.05729576572775841
# #################
# # EPOCH 2175
# #################
# AVERAGE TRAIN LOSS: 0.024374810978770256
# AVERAGE VAL LOSS: 0.05845647677779198
# #################
# # EPOCH 2176
# #################
# AVERAGE TRAIN LOSS: 0.019211307168006897
# AVERAGE VAL LOSS: 0.07013905048370361
# #################
# # EPOCH 2177
# #################
# AVERAGE TRAIN LOSS: 0.02206181176006794
# AVERAGE VAL LOSS: 0.061075031757354736
# #################
# # EPOCH 2178
# #################
# AVERAGE TRAIN LOSS: 0.01859748363494873
# AVERAGE VAL LOSS: 0.05712571367621422
# #################
# # EPOCH 2179
# #################
# AVERAGE TRAIN LOSS: 0.021212127059698105
# AVERAGE VAL LOSS: 0.059577565640211105
# #################
# # EPOCH 2180
# #################
# AVERAGE TRAIN LOSS: 0.020566534250974655
# AVERAGE VAL LOSS: 0.05828886106610298
# #################
# # EPOCH 2181
# #################
# AVERAGE TRAIN LOSS: 0.02463196963071823
# AVERAGE VAL LOSS: 0.0654292032122612
# #################
# # EPOCH 2182
# #################
# AVERAGE TRAIN LOSS: 0.02087346836924553
# AVERAGE VAL LOSS: 0.05934178829193115
# #################
# # EPOCH 2183
# #################
# AVERAGE TRAIN LOSS: 0.02090137079358101
# AVERAGE VAL LOSS: 0.06289892643690109
# #################
# # EPOCH 2184
# #################
# AVERAGE TRAIN LOSS: 0.019428666681051254
# AVERAGE VAL LOSS: 0.05989357456564903
# #################
# # EPOCH 2185
# #################
# AVERAGE TRAIN LOSS: 0.023920368403196335
# AVERAGE VAL LOSS: 0.05721930414438248
# #################
# # EPOCH 2186
# #################
# AVERAGE TRAIN LOSS: 0.019971370697021484
# AVERAGE VAL LOSS: 0.07077545672655106
# #################
# # EPOCH 2187
# #################
# AVERAGE TRAIN LOSS: 0.02190146967768669
# AVERAGE VAL LOSS: 0.060596615076065063
# #################
# # EPOCH 2188
# #################
# AVERAGE TRAIN LOSS: 0.020622175186872482
# AVERAGE VAL LOSS: 0.05904669687151909
# #################
# # EPOCH 2189
# #################
# AVERAGE TRAIN LOSS: 0.019684171304106712
# AVERAGE VAL LOSS: 0.06406636536121368
# #################
# # EPOCH 2190
# #################
# AVERAGE TRAIN LOSS: 0.019751733168959618
# AVERAGE VAL LOSS: 0.0633992925286293
# #################
# # EPOCH 2191
# #################
# AVERAGE TRAIN LOSS: 0.019328156486153603
# AVERAGE VAL LOSS: 0.05871573090553284
# #################
# # EPOCH 2192
# #################
# AVERAGE TRAIN LOSS: 0.02199125662446022
# AVERAGE VAL LOSS: 0.061330646276474
# #################
# # EPOCH 2193
# #################
# AVERAGE TRAIN LOSS: 0.019379572942852974
# AVERAGE VAL LOSS: 0.05941111594438553
# #################
# # EPOCH 2194
# #################
# AVERAGE TRAIN LOSS: 0.019284328445792198
# AVERAGE VAL LOSS: 0.05704868584871292
# #################
# # EPOCH 2195
# #################
# AVERAGE TRAIN LOSS: 0.026655549183487892
# AVERAGE VAL LOSS: 0.06659764051437378
# #################
# # EPOCH 2196
# #################
# AVERAGE TRAIN LOSS: 0.01889881305396557
# AVERAGE VAL LOSS: 0.05738906189799309
# #################
# # EPOCH 2197
# #################
# AVERAGE TRAIN LOSS: 0.02309066615998745
# AVERAGE VAL LOSS: 0.05791391804814339
# #################
# # EPOCH 2198
# #################
# AVERAGE TRAIN LOSS: 0.019663166254758835
# AVERAGE VAL LOSS: 0.06947844475507736
# #################
# # EPOCH 2199
# #################
# AVERAGE TRAIN LOSS: 0.024341043084859848
# AVERAGE VAL LOSS: 0.0596315823495388
# #################
# # EPOCH 2200
# #################
# AVERAGE TRAIN LOSS: 0.0192640982568264
# AVERAGE VAL LOSS: 0.06271551549434662
# #################
# # EPOCH 2201
# #################
# AVERAGE TRAIN LOSS: 0.020475193858146667
# AVERAGE VAL LOSS: 0.06273383647203445
# #################
# # EPOCH 2202
# #################
# AVERAGE TRAIN LOSS: 0.01937972567975521
# AVERAGE VAL LOSS: 0.057368453592061996
# #################
# # EPOCH 2203
# #################
# AVERAGE TRAIN LOSS: 0.019966181367635727
# AVERAGE VAL LOSS: 0.06045365333557129
# #################
# # EPOCH 2204
# #################
# AVERAGE TRAIN LOSS: 0.019831568002700806
# AVERAGE VAL LOSS: 0.06488468497991562
# #################
# # EPOCH 2205
# #################
# AVERAGE TRAIN LOSS: 0.020298484712839127
# AVERAGE VAL LOSS: 0.05803670361638069
# #################
# # EPOCH 2206
# #################
# AVERAGE TRAIN LOSS: 0.020032469183206558
# AVERAGE VAL LOSS: 0.06128904968500137
# #################
# # EPOCH 2207
# #################
# AVERAGE TRAIN LOSS: 0.020467933267354965
# AVERAGE VAL LOSS: 0.06329571455717087
# #################
# # EPOCH 2208
# #################
# AVERAGE TRAIN LOSS: 0.01879217103123665
# AVERAGE VAL LOSS: 0.060936249792575836
# #################
# # EPOCH 2209
# #################
# AVERAGE TRAIN LOSS: 0.01991557888686657
# AVERAGE VAL LOSS: 0.05881354957818985
# #################
# # EPOCH 2210
# #################
# AVERAGE TRAIN LOSS: 0.019242186099290848
# AVERAGE VAL LOSS: 0.06305887550115585
# #################
# # EPOCH 2211
# #################
# AVERAGE TRAIN LOSS: 0.019864823669195175
# AVERAGE VAL LOSS: 0.06424770504236221
# #################
# # EPOCH 2212
# #################
# AVERAGE TRAIN LOSS: 0.021321836858987808
# AVERAGE VAL LOSS: 0.05807352066040039
# #################
# # EPOCH 2213
# #################
# AVERAGE TRAIN LOSS: 0.019509783014655113
# AVERAGE VAL LOSS: 0.06161921098828316
# #################
# # EPOCH 2214
# #################
# AVERAGE TRAIN LOSS: 0.020913705229759216
# AVERAGE VAL LOSS: 0.06126317009329796
# #################
# # EPOCH 2215
# #################
# AVERAGE TRAIN LOSS: 0.019691437482833862
# AVERAGE VAL LOSS: 0.06344664096832275
# #################
# # EPOCH 2216
# #################
# AVERAGE TRAIN LOSS: 0.01968196965754032
# AVERAGE VAL LOSS: 0.059829678386449814
# #################
# # EPOCH 2217
# #################
# AVERAGE TRAIN LOSS: 0.019872380420565605
# AVERAGE VAL LOSS: 0.05710921436548233
# #################
# # EPOCH 2218
# #################
# AVERAGE TRAIN LOSS: 0.02011933922767639
# AVERAGE VAL LOSS: 0.05917040631175041
# #################
# # EPOCH 2219
# #################
# AVERAGE TRAIN LOSS: 0.020547810941934586
# AVERAGE VAL LOSS: 0.06307363510131836
# #################
# # EPOCH 2220
# #################
# AVERAGE TRAIN LOSS: 0.01956929638981819
# AVERAGE VAL LOSS: 0.06242078170180321
# #################
# # EPOCH 2221
# #################
# AVERAGE TRAIN LOSS: 0.021360969170928
# AVERAGE VAL LOSS: 0.05788503959774971
# #################
# # EPOCH 2222
# #################
# AVERAGE TRAIN LOSS: 0.019284848123788834
# AVERAGE VAL LOSS: 0.06486377120018005
# #################
# # EPOCH 2223
# #################
# AVERAGE TRAIN LOSS: 0.021028751507401466
# AVERAGE VAL LOSS: 0.0639558956027031
# #################
# # EPOCH 2224
# #################
# AVERAGE TRAIN LOSS: 0.018871638923883438
# AVERAGE VAL LOSS: 0.058236729353666306
# #################
# # EPOCH 2225
# #################
# AVERAGE TRAIN LOSS: 0.020886356011033058
# AVERAGE VAL LOSS: 0.058760304003953934
# #################
# # EPOCH 2226
# #################
# AVERAGE TRAIN LOSS: 0.022305911406874657
# AVERAGE VAL LOSS: 0.0675126165151596
# #################
# # EPOCH 2227
# #################
# AVERAGE TRAIN LOSS: 0.022922920063138008
# AVERAGE VAL LOSS: 0.05921120569109917
# #################
# # EPOCH 2228
# #################
# AVERAGE TRAIN LOSS: 0.019316652789711952
# AVERAGE VAL LOSS: 0.06257094442844391
# #################
# # EPOCH 2229
# #################
# AVERAGE TRAIN LOSS: 0.019714556634426117
# AVERAGE VAL LOSS: 0.06343843042850494
# #################
# # EPOCH 2230
# #################
# AVERAGE TRAIN LOSS: 0.019541773945093155
# AVERAGE VAL LOSS: 0.058925509452819824
# #################
# # EPOCH 2231
# #################
# AVERAGE TRAIN LOSS: 0.020432619377970695
# AVERAGE VAL LOSS: 0.057784657925367355
# #################
# # EPOCH 2232
# #################
# AVERAGE TRAIN LOSS: 0.018650589510798454
# AVERAGE VAL LOSS: 0.06308629363775253
# #################
# # EPOCH 2233
# #################
# AVERAGE TRAIN LOSS: 0.021533776074647903
# AVERAGE VAL LOSS: 0.06187230348587036
# #################
# # EPOCH 2234
# #################
# AVERAGE TRAIN LOSS: 0.02200694940984249
# AVERAGE VAL LOSS: 0.06847816705703735
# #################
# # EPOCH 2235
# #################
# AVERAGE TRAIN LOSS: 0.02542228437960148
# AVERAGE VAL LOSS: 0.0586201548576355
# #################
# # EPOCH 2236
# #################
# AVERAGE TRAIN LOSS: 0.019270343706011772
# AVERAGE VAL LOSS: 0.062430646270513535
# #################
# # EPOCH 2237
# #################
# AVERAGE TRAIN LOSS: 0.021834250539541245
# AVERAGE VAL LOSS: 0.06941556185483932
# #################
# # EPOCH 2238
# #################
# AVERAGE TRAIN LOSS: 0.019315650686621666
# AVERAGE VAL LOSS: 0.05936160311102867
# #################
# # EPOCH 2239
# #################
# AVERAGE TRAIN LOSS: 0.020953277125954628
# AVERAGE VAL LOSS: 0.05838702246546745
# #################
# # EPOCH 2240
# #################
# AVERAGE TRAIN LOSS: 0.018435124307870865
# AVERAGE VAL LOSS: 0.06407773494720459
# #################
# # EPOCH 2241
# #################
# AVERAGE TRAIN LOSS: 0.023549309000372887
# AVERAGE VAL LOSS: 0.06807705014944077
# #################
# # EPOCH 2242
# #################
# AVERAGE TRAIN LOSS: 0.01821635290980339
# AVERAGE VAL LOSS: 0.057497538626194
# #################
# # EPOCH 2243
# #################
# AVERAGE TRAIN LOSS: 0.022095289081335068
# AVERAGE VAL LOSS: 0.05882091447710991
# #################
# # EPOCH 2244
# #################
# AVERAGE TRAIN LOSS: 0.025647198781371117
# AVERAGE VAL LOSS: 0.06944858282804489
# #################
# # EPOCH 2245
# #################
# AVERAGE TRAIN LOSS: 0.018190260976552963
# AVERAGE VAL LOSS: 0.05813140422105789
# #################
# # EPOCH 2246
# #################
# AVERAGE TRAIN LOSS: 0.022264692932367325
# AVERAGE VAL LOSS: 0.0570392906665802
# #################
# # EPOCH 2247
# #################
# AVERAGE TRAIN LOSS: 0.02215324342250824
# AVERAGE VAL LOSS: 0.06610597670078278
# #################
# # EPOCH 2248
# #################
# AVERAGE TRAIN LOSS: 0.02020248956978321
# AVERAGE VAL LOSS: 0.06032447889447212
# #################
# # EPOCH 2249
# #################
# AVERAGE TRAIN LOSS: 0.01937270537018776
# AVERAGE VAL LOSS: 0.06021380424499512
# #################
# # EPOCH 2250
# #################
# AVERAGE TRAIN LOSS: 0.020490504801273346
# AVERAGE VAL LOSS: 0.05685853585600853
# #################
# # EPOCH 2251
# #################
# AVERAGE TRAIN LOSS: 0.02033948339521885
# AVERAGE VAL LOSS: 0.06332134455442429
# #################
# # EPOCH 2252
# #################
# AVERAGE TRAIN LOSS: 0.019402187317609787
# AVERAGE VAL LOSS: 0.064999520778656
# #################
# # EPOCH 2253
# #################
# AVERAGE TRAIN LOSS: 0.020643135532736778
# AVERAGE VAL LOSS: 0.05865785479545593
# #################
# # EPOCH 2254
# #################
# AVERAGE TRAIN LOSS: 0.018953919410705566
# AVERAGE VAL LOSS: 0.06293369084596634
# #################
# # EPOCH 2255
# #################
# AVERAGE TRAIN LOSS: 0.021022291854023933
# AVERAGE VAL LOSS: 0.0640576183795929
# #################
# # EPOCH 2256
# #################
# AVERAGE TRAIN LOSS: 0.02153823897242546
# AVERAGE VAL LOSS: 0.05764758586883545
# #################
# # EPOCH 2257
# #################
# AVERAGE TRAIN LOSS: 0.020052537322044373
# AVERAGE VAL LOSS: 0.06262580305337906
# #################
# # EPOCH 2258
# #################
# AVERAGE TRAIN LOSS: 0.01989722065627575
# AVERAGE VAL LOSS: 0.06123165041208267
# #################
# # EPOCH 2259
# #################
# AVERAGE TRAIN LOSS: 0.022188609465956688
# AVERAGE VAL LOSS: 0.05853932723402977
# #################
# # EPOCH 2260
# #################
# AVERAGE TRAIN LOSS: 0.020129701122641563
# AVERAGE VAL LOSS: 0.06549496948719025
# #################
# # EPOCH 2261
# #################
# AVERAGE TRAIN LOSS: 0.019711550325155258
# AVERAGE VAL LOSS: 0.0628165602684021
# #################
# # EPOCH 2262
# #################
# AVERAGE TRAIN LOSS: 0.02110983058810234
# AVERAGE VAL LOSS: 0.060468580573797226
# #################
# # EPOCH 2263
# #################
# AVERAGE TRAIN LOSS: 0.01916106417775154
# AVERAGE VAL LOSS: 0.06113826110959053
# #################
# # EPOCH 2264
# #################
# AVERAGE TRAIN LOSS: 0.025381598621606827
# AVERAGE VAL LOSS: 0.0667213425040245
# #################
# # EPOCH 2265
# #################
# AVERAGE TRAIN LOSS: 0.023169884458184242
# AVERAGE VAL LOSS: 0.0550319068133831
# #################
# # EPOCH 2266
# #################
# AVERAGE TRAIN LOSS: 0.0214951541274786
# AVERAGE VAL LOSS: 0.06185280159115791
# #################
# # EPOCH 2267
# #################
# AVERAGE TRAIN LOSS: 0.02033846452832222
# AVERAGE VAL LOSS: 0.06150022894144058
# #################
# # EPOCH 2268
# #################
# AVERAGE TRAIN LOSS: 0.01909860037267208
# AVERAGE VAL LOSS: 0.0642133429646492
# #################
# # EPOCH 2269
# #################
# AVERAGE TRAIN LOSS: 0.02254968322813511
# AVERAGE VAL LOSS: 0.06650680303573608
# #################
# # EPOCH 2270
# #################
# AVERAGE TRAIN LOSS: 0.01836356520652771
# AVERAGE VAL LOSS: 0.06088683009147644
# #################
# # EPOCH 2271
# #################
# AVERAGE TRAIN LOSS: 0.019862454384565353
# AVERAGE VAL LOSS: 0.059554994106292725
# #################
# # EPOCH 2272
# #################
# AVERAGE TRAIN LOSS: 0.01896960660815239
# AVERAGE VAL LOSS: 0.06230353191494942
# #################
# # EPOCH 2273
# #################
# AVERAGE TRAIN LOSS: 0.019935544580221176
# AVERAGE VAL LOSS: 0.06257844716310501
# #################
# # EPOCH 2274
# #################
# AVERAGE TRAIN LOSS: 0.021204626187682152
# AVERAGE VAL LOSS: 0.05751549080014229
# #################
# # EPOCH 2275
# #################
# AVERAGE TRAIN LOSS: 0.020145956426858902
# AVERAGE VAL LOSS: 0.05943375825881958
# #################
# # EPOCH 2276
# #################
# AVERAGE TRAIN LOSS: 0.021616721525788307
# AVERAGE VAL LOSS: 0.07164497673511505
# #################
# # EPOCH 2277
# #################
# AVERAGE TRAIN LOSS: 0.01972128450870514
# AVERAGE VAL LOSS: 0.06118546798825264
# #################
# # EPOCH 2278
# #################
# AVERAGE TRAIN LOSS: 0.023271003738045692
# AVERAGE VAL LOSS: 0.06128566339612007
# #################
# # EPOCH 2279
# #################
# AVERAGE TRAIN LOSS: 0.01985991932451725
# AVERAGE VAL LOSS: 0.07060656696557999
# #################
# # EPOCH 2280
# #################
# AVERAGE TRAIN LOSS: 0.026094000786542892
# AVERAGE VAL LOSS: 0.06937378644943237
# #################
# # EPOCH 2281
# #################
# AVERAGE TRAIN LOSS: 0.022895704954862595
# AVERAGE VAL LOSS: 0.056188102811574936
# #################
# # EPOCH 2282
# #################
# AVERAGE TRAIN LOSS: 0.022773386910557747
# AVERAGE VAL LOSS: 0.06458508223295212
# #################
# # EPOCH 2283
# #################
# AVERAGE TRAIN LOSS: 0.019772598519921303
# AVERAGE VAL LOSS: 0.06378143280744553
# #################
# # EPOCH 2284
# #################
# AVERAGE TRAIN LOSS: 0.02033848688006401
# AVERAGE VAL LOSS: 0.05749962851405144
# #################
# # EPOCH 2285
# #################
# AVERAGE TRAIN LOSS: 0.020921524614095688
# AVERAGE VAL LOSS: 0.0627434030175209
# #################
# # EPOCH 2286
# #################
# AVERAGE TRAIN LOSS: 0.019752122461795807
# AVERAGE VAL LOSS: 0.0634487196803093
# #################
# # EPOCH 2287
# #################
# AVERAGE TRAIN LOSS: 0.01857886277139187
# AVERAGE VAL LOSS: 0.060035403817892075
# #################
# # EPOCH 2288
# #################
# AVERAGE TRAIN LOSS: 0.0199027881026268
# AVERAGE VAL LOSS: 0.0594196580350399
# #################
# # EPOCH 2289
# #################
# AVERAGE TRAIN LOSS: 0.019541535526514053
# AVERAGE VAL LOSS: 0.06377539783716202
# #################
# # EPOCH 2290
# #################
# AVERAGE TRAIN LOSS: 0.019805241376161575
# AVERAGE VAL LOSS: 0.0602349154651165
# #################
# # EPOCH 2291
# #################
# AVERAGE TRAIN LOSS: 0.01978885754942894
# AVERAGE VAL LOSS: 0.06030282378196716
# #################
# # EPOCH 2292
# #################
# AVERAGE TRAIN LOSS: 0.018962552770972252
# AVERAGE VAL LOSS: 0.058371126651763916
# #################
# # EPOCH 2293
# #################
# AVERAGE TRAIN LOSS: 0.019932560622692108
# AVERAGE VAL LOSS: 0.06057557463645935
# #################
# # EPOCH 2294
# #################
# AVERAGE TRAIN LOSS: 0.018937978893518448
# AVERAGE VAL LOSS: 0.06427332013845444
# #################
# # EPOCH 2295
# #################
# AVERAGE TRAIN LOSS: 0.019538717344403267
# AVERAGE VAL LOSS: 0.06322136521339417
# #################
# # EPOCH 2296
# #################
# AVERAGE TRAIN LOSS: 0.019842160865664482
# AVERAGE VAL LOSS: 0.058848705142736435
# #################
# # EPOCH 2297
# #################
# AVERAGE TRAIN LOSS: 0.0194093007594347
# AVERAGE VAL LOSS: 0.05836569145321846
# #################
# # EPOCH 2298
# #################
# AVERAGE TRAIN LOSS: 0.019674230366945267
# AVERAGE VAL LOSS: 0.06254687160253525
# #################
# # EPOCH 2299
# #################
# AVERAGE TRAIN LOSS: 0.01924133487045765
# AVERAGE VAL LOSS: 0.06397351622581482
# #################
# # EPOCH 2300
# #################
# AVERAGE TRAIN LOSS: 0.019212855026125908
# AVERAGE VAL LOSS: 0.06127435714006424
# #################
# # EPOCH 2301
# #################
# AVERAGE TRAIN LOSS: 0.020149152725934982
# AVERAGE VAL LOSS: 0.06065420061349869
# #################
# # EPOCH 2302
# #################
# AVERAGE TRAIN LOSS: 0.01981605589389801
# AVERAGE VAL LOSS: 0.06303471326828003
# #################
# # EPOCH 2303
# #################
# AVERAGE TRAIN LOSS: 0.021936925128102303
# AVERAGE VAL LOSS: 0.06386388838291168
# #################
# # EPOCH 2304
# #################
# AVERAGE TRAIN LOSS: 0.02250956930220127
# AVERAGE VAL LOSS: 0.05616004392504692
# #################
# # EPOCH 2305
# #################
# AVERAGE TRAIN LOSS: 0.019446801394224167
# AVERAGE VAL LOSS: 0.06268439441919327
# #################
# # EPOCH 2306
# #################
# AVERAGE TRAIN LOSS: 0.023560456931591034
# AVERAGE VAL LOSS: 0.06974130868911743
# #################
# # EPOCH 2307
# #################
# AVERAGE TRAIN LOSS: 0.01900649443268776
# AVERAGE VAL LOSS: 0.05735474452376366
# #################
# # EPOCH 2308
# #################
# AVERAGE TRAIN LOSS: 0.022869635373353958
# AVERAGE VAL LOSS: 0.05996983125805855
# #################
# # EPOCH 2309
# #################
# AVERAGE TRAIN LOSS: 0.019201304763555527
# AVERAGE VAL LOSS: 0.06551337242126465
# #################
# # EPOCH 2310
# #################
# AVERAGE TRAIN LOSS: 0.020222466439008713
# AVERAGE VAL LOSS: 0.06142100319266319
# #################
# # EPOCH 2311
# #################
# AVERAGE TRAIN LOSS: 0.019783932715654373
# AVERAGE VAL LOSS: 0.05785152316093445
# #################
# # EPOCH 2312
# #################
# AVERAGE TRAIN LOSS: 0.0205678828060627
# AVERAGE VAL LOSS: 0.060604311525821686
# #################
# # EPOCH 2313
# #################
# AVERAGE TRAIN LOSS: 0.01873784326016903
# AVERAGE VAL LOSS: 0.06666404008865356
# #################
# # EPOCH 2314
# #################
# AVERAGE TRAIN LOSS: 0.021819233894348145
# AVERAGE VAL LOSS: 0.06257551908493042
# #################
# # EPOCH 2315
# #################
# AVERAGE TRAIN LOSS: 0.020292896777391434
# AVERAGE VAL LOSS: 0.06011822447180748
# #################
# # EPOCH 2316
# #################
# AVERAGE TRAIN LOSS: 0.022683849558234215
# AVERAGE VAL LOSS: 0.05798164755105972
# #################
# # EPOCH 2317
# #################
# AVERAGE TRAIN LOSS: 0.021390775218605995
# AVERAGE VAL LOSS: 0.06449385732412338
# #################
# # EPOCH 2318
# #################
# AVERAGE TRAIN LOSS: 0.021299520507454872
# AVERAGE VAL LOSS: 0.06148577481508255
# #################
# # EPOCH 2319
# #################
# AVERAGE TRAIN LOSS: 0.01871495693922043
# AVERAGE VAL LOSS: 0.059607040137052536
# #################
# # EPOCH 2320
# #################
# AVERAGE TRAIN LOSS: 0.019390027970075607
# AVERAGE VAL LOSS: 0.06011638790369034
# #################
# # EPOCH 2321
# #################
# AVERAGE TRAIN LOSS: 0.02034042775630951
# AVERAGE VAL LOSS: 0.06290733069181442
# #################
# # EPOCH 2322
# #################
# AVERAGE TRAIN LOSS: 0.020271215587854385
# AVERAGE VAL LOSS: 0.061925459653139114
# #################
# # EPOCH 2323
# #################
# AVERAGE TRAIN LOSS: 0.01993388868868351
# AVERAGE VAL LOSS: 0.06341060250997543
# #################
# # EPOCH 2324
# #################
# AVERAGE TRAIN LOSS: 0.020745310932397842
# AVERAGE VAL LOSS: 0.057884931564331055
# #################
# # EPOCH 2325
# #################
# AVERAGE TRAIN LOSS: 0.019675711169838905
# AVERAGE VAL LOSS: 0.05997812747955322
# #################
# # EPOCH 2326
# #################
# AVERAGE TRAIN LOSS: 0.020007098093628883
# AVERAGE VAL LOSS: 0.06384434551000595
# #################
# # EPOCH 2327
# #################
# AVERAGE TRAIN LOSS: 0.018684176728129387
# AVERAGE VAL LOSS: 0.05979981645941734
# #################
# # EPOCH 2328
# #################
# AVERAGE TRAIN LOSS: 0.02063911035656929
# AVERAGE VAL LOSS: 0.06172337755560875
# #################
# # EPOCH 2329
# #################
# AVERAGE TRAIN LOSS: 0.02101675048470497
# AVERAGE VAL LOSS: 0.06637117266654968
# #################
# # EPOCH 2330
# #################
# AVERAGE TRAIN LOSS: 0.01971825584769249
# AVERAGE VAL LOSS: 0.058977313339710236
# #################
# # EPOCH 2331
# #################
# AVERAGE TRAIN LOSS: 0.019866060465574265
# AVERAGE VAL LOSS: 0.061608750373125076
# #################
# # EPOCH 2332
# #################
# AVERAGE TRAIN LOSS: 0.020117072388529778
# AVERAGE VAL LOSS: 0.05986220762133598
# #################
# # EPOCH 2333
# #################
# AVERAGE TRAIN LOSS: 0.019119782373309135
# AVERAGE VAL LOSS: 0.06337616592645645
# #################
# # EPOCH 2334
# #################
# AVERAGE TRAIN LOSS: 0.019596166908740997
# AVERAGE VAL LOSS: 0.063376784324646
# #################
# # EPOCH 2335
# #################
# AVERAGE TRAIN LOSS: 0.01891755685210228
# AVERAGE VAL LOSS: 0.06164701655507088
# #################
# # EPOCH 2336
# #################
# AVERAGE TRAIN LOSS: 0.021824583411216736
# AVERAGE VAL LOSS: 0.057734597474336624
# #################
# # EPOCH 2337
# #################
# AVERAGE TRAIN LOSS: 0.025587718933820724
# AVERAGE VAL LOSS: 0.07219601422548294
# #################
# # EPOCH 2338
# #################
# AVERAGE TRAIN LOSS: 0.02233373001217842
# AVERAGE VAL LOSS: 0.05858805775642395
# #################
# # EPOCH 2339
# #################
# AVERAGE TRAIN LOSS: 0.02105618827044964
# AVERAGE VAL LOSS: 0.059224437922239304
# #################
# # EPOCH 2340
# #################
# AVERAGE TRAIN LOSS: 0.019380854442715645
# AVERAGE VAL LOSS: 0.06380748003721237
# #################
# # EPOCH 2341
# #################
# AVERAGE TRAIN LOSS: 0.019297372549772263
# AVERAGE VAL LOSS: 0.061412662267684937
# #################
# # EPOCH 2342
# #################
# AVERAGE TRAIN LOSS: 0.019192973151803017
# AVERAGE VAL LOSS: 0.05925886705517769
# #################
# # EPOCH 2343
# #################
# AVERAGE TRAIN LOSS: 0.021155398339033127
# AVERAGE VAL LOSS: 0.05936649441719055
# #################
# # EPOCH 2344
# #################
# AVERAGE TRAIN LOSS: 0.021404024213552475
# AVERAGE VAL LOSS: 0.07065583765506744
# #################
# # EPOCH 2345
# #################
# AVERAGE TRAIN LOSS: 0.02066463977098465
# AVERAGE VAL LOSS: 0.06161562353372574
# #################
# # EPOCH 2346
# #################
# AVERAGE TRAIN LOSS: 0.019986972212791443
# AVERAGE VAL LOSS: 0.05850571021437645
# #################
# # EPOCH 2347
# #################
# AVERAGE TRAIN LOSS: 0.021190430968999863
# AVERAGE VAL LOSS: 0.06419074535369873
# #################
# # EPOCH 2348
# #################
# AVERAGE TRAIN LOSS: 0.019982311874628067
# AVERAGE VAL LOSS: 0.06122219190001488
# #################
# # EPOCH 2349
# #################
# AVERAGE TRAIN LOSS: 0.019965652376413345
# AVERAGE VAL LOSS: 0.05799949914216995
# #################
# # EPOCH 2350
# #################
# AVERAGE TRAIN LOSS: 0.019100377336144447
# AVERAGE VAL LOSS: 0.06075705960392952
# #################
# # EPOCH 2351
# #################
# AVERAGE TRAIN LOSS: 0.018941884860396385
# AVERAGE VAL LOSS: 0.061714112758636475
# #################
# # EPOCH 2352
# #################
# AVERAGE TRAIN LOSS: 0.019255906343460083
# AVERAGE VAL LOSS: 0.060433682054281235
# #################
# # EPOCH 2353
# #################
# AVERAGE TRAIN LOSS: 0.019110357388854027
# AVERAGE VAL LOSS: 0.06031394004821777
# #################
# # EPOCH 2354
# #################
# AVERAGE TRAIN LOSS: 0.020450467243790627
# AVERAGE VAL LOSS: 0.06329195946455002
# #################
# # EPOCH 2355
# #################
# AVERAGE TRAIN LOSS: 0.02146773971617222
# AVERAGE VAL LOSS: 0.06022004410624504
# #################
# # EPOCH 2356
# #################
# AVERAGE TRAIN LOSS: 0.019747836515307426
# AVERAGE VAL LOSS: 0.06455554813146591
# #################
# # EPOCH 2357
# #################
# AVERAGE TRAIN LOSS: 0.019524523988366127
# AVERAGE VAL LOSS: 0.06069577857851982
# #################
# # EPOCH 2358
# #################
# AVERAGE TRAIN LOSS: 0.02006799913942814
# AVERAGE VAL LOSS: 0.0583590529859066
# #################
# # EPOCH 2359
# #################
# AVERAGE TRAIN LOSS: 0.01957140862941742
# AVERAGE VAL LOSS: 0.059747230261564255
# #################
# # EPOCH 2360
# #################
# AVERAGE TRAIN LOSS: 0.01945987157523632
# AVERAGE VAL LOSS: 0.06352440267801285
# #################
# # EPOCH 2361
# #################
# AVERAGE TRAIN LOSS: 0.020650841295719147
# AVERAGE VAL LOSS: 0.05907423421740532
# #################
# # EPOCH 2362
# #################
# AVERAGE TRAIN LOSS: 0.020220793783664703
# AVERAGE VAL LOSS: 0.06373268365859985
# #################
# # EPOCH 2363
# #################
# AVERAGE TRAIN LOSS: 0.020515484735369682
# AVERAGE VAL LOSS: 0.05883758142590523
# #################
# # EPOCH 2364
# #################
# AVERAGE TRAIN LOSS: 0.020769456401467323
# AVERAGE VAL LOSS: 0.058682024478912354
# #################
# # EPOCH 2365
# #################
# AVERAGE TRAIN LOSS: 0.018758054822683334
# AVERAGE VAL LOSS: 0.06494162231683731
# #################
# # EPOCH 2366
# #################
# AVERAGE TRAIN LOSS: 0.0193675197660923
# AVERAGE VAL LOSS: 0.06375841051340103
# #################
# # EPOCH 2367
# #################
# AVERAGE TRAIN LOSS: 0.02025204710662365
# AVERAGE VAL LOSS: 0.06115609407424927
# #################
# # EPOCH 2368
# #################
# AVERAGE TRAIN LOSS: 0.019209008663892746
# AVERAGE VAL LOSS: 0.05813678726553917
# #################
# # EPOCH 2369
# #################
# AVERAGE TRAIN LOSS: 0.019487779587507248
# AVERAGE VAL LOSS: 0.06070569157600403
# #################
# # EPOCH 2370
# #################
# AVERAGE TRAIN LOSS: 0.019245021045207977
# AVERAGE VAL LOSS: 0.0666741356253624
# #################
# # EPOCH 2371
# #################
# AVERAGE TRAIN LOSS: 0.021183114498853683
# AVERAGE VAL LOSS: 0.05959654971957207
# #################
# # EPOCH 2372
# #################
# AVERAGE TRAIN LOSS: 0.01947735622525215
# AVERAGE VAL LOSS: 0.06214805319905281
# #################
# # EPOCH 2373
# #################
# AVERAGE TRAIN LOSS: 0.0211621280759573
# AVERAGE VAL LOSS: 0.0599575936794281
# #################
# # EPOCH 2374
# #################
# AVERAGE TRAIN LOSS: 0.0198565311729908
# AVERAGE VAL LOSS: 0.0583137683570385
# #################
# # EPOCH 2375
# #################
# ...
# #################
# # EPOCH 2875
# #################
# AVERAGE TRAIN LOSS: 0.01926397532224655
# AVERAGE VAL LOSS: 0.0595843568444252
# #################
# # EPOCH 2876
# #################
# AVERAGE TRAIN LOSS: 0.019547665491700172
# AVERAGE VAL LOSS: 0.06195629760622978
# #################
# # EPOCH 2877
# #################
# AVERAGE TRAIN LOSS: 0.018997695297002792
# AVERAGE VAL LOSS: 0.06054924800992012
# #################
# # EPOCH 2878
# #################
# AVERAGE TRAIN LOSS: 0.023560311645269394
# AVERAGE VAL LOSS: 0.058263182640075684
# #################
# # EPOCH 2879
# #################
# AVERAGE TRAIN LOSS: 0.021418798714876175
# AVERAGE VAL LOSS: 0.0679544135928154
# #################
# # EPOCH 2880
# #################
# AVERAGE TRAIN LOSS: 0.019868839532136917
# AVERAGE VAL LOSS: 0.06304268538951874
# #################
# # EPOCH 2881
# #################
# AVERAGE TRAIN LOSS: 0.020366523414850235
# AVERAGE VAL LOSS: 0.058800168335437775
# #################
# # EPOCH 2882
# #################
# AVERAGE TRAIN LOSS: 0.02051403373479843
# AVERAGE VAL LOSS: 0.060049500316381454
# #################
# # EPOCH 2883
# #################
# AVERAGE TRAIN LOSS: 0.018118966370821
# AVERAGE VAL LOSS: 0.06730357557535172
# #################
# # EPOCH 2884
# #################
# AVERAGE TRAIN LOSS: 0.022800486534833908
# AVERAGE VAL LOSS: 0.06577363610267639
# #################
# # EPOCH 2885
# #################
# AVERAGE TRAIN LOSS: 0.019110094755887985
# AVERAGE VAL LOSS: 0.05712052807211876
# #################
# # EPOCH 2886
# #################
# AVERAGE TRAIN LOSS: 0.021225929260253906
# AVERAGE VAL LOSS: 0.060605622828006744
# #################
# # EPOCH 2887
# #################
# AVERAGE TRAIN LOSS: 0.018940778449177742
# AVERAGE VAL LOSS: 0.061389435082674026
# #################
# # EPOCH 2888
# #################
# AVERAGE TRAIN LOSS: 0.019118551164865494
# AVERAGE VAL LOSS: 0.06306001543998718
# #################
# # EPOCH 2889
# #################
# AVERAGE TRAIN LOSS: 0.020340578630566597
# AVERAGE VAL LOSS: 0.06399243324995041
# #################
# # EPOCH 2890
# #################
# AVERAGE TRAIN LOSS: 0.02557578682899475
# AVERAGE VAL LOSS: 0.056457411497831345
# #################
# # EPOCH 2891
# #################
# AVERAGE TRAIN LOSS: 0.022002289071679115
# AVERAGE VAL LOSS: 0.06597390025854111
# #################
# # EPOCH 2892
# #################
# AVERAGE TRAIN LOSS: 0.021364271640777588
# AVERAGE VAL LOSS: 0.06399000436067581
# #################
# # EPOCH 2893
# #################
# AVERAGE TRAIN LOSS: 0.02070334553718567
# AVERAGE VAL LOSS: 0.057538606226444244
# #################
# # EPOCH 2894
# #################
# AVERAGE TRAIN LOSS: 0.020515862852334976
# AVERAGE VAL LOSS: 0.05722006782889366
# #################
# # EPOCH 2895
# #################
# AVERAGE TRAIN LOSS: 0.018163371831178665
# AVERAGE VAL LOSS: 0.06266389042139053
# #################
# # EPOCH 2896
# #################
# AVERAGE TRAIN LOSS: 0.019446510821580887
# AVERAGE VAL LOSS: 0.06533046811819077
# #################
# # EPOCH 2897
# #################
# AVERAGE TRAIN LOSS: 0.02115621790289879
# AVERAGE VAL LOSS: 0.05824936553835869
# #################
# # EPOCH 2898
# #################
# AVERAGE TRAIN LOSS: 0.02104397863149643
# AVERAGE VAL LOSS: 0.05959323048591614
# #################
# # EPOCH 2899
# #################
# AVERAGE TRAIN LOSS: 0.019619420170783997
# AVERAGE VAL LOSS: 0.06831575185060501
# #################
# # EPOCH 2900
# #################
# AVERAGE TRAIN LOSS: 0.02005521021783352
# AVERAGE VAL LOSS: 0.06125752255320549
# #################
# # EPOCH 2901
# #################
# AVERAGE TRAIN LOSS: 0.018467888236045837
# AVERAGE VAL LOSS: 0.05766033008694649
# #################
# # EPOCH 2902
# #################
# AVERAGE TRAIN LOSS: 0.02271183393895626
# AVERAGE VAL LOSS: 0.060647476464509964
# #################
# # EPOCH 2903
# #################
# AVERAGE TRAIN LOSS: 0.018714064732193947
# AVERAGE VAL LOSS: 0.05973055586218834
# #################
# # EPOCH 2904
# #################
# AVERAGE TRAIN LOSS: 0.020596858114004135
# AVERAGE VAL LOSS: 0.05888257548213005
# #################
# # EPOCH 2905
# #################
# AVERAGE TRAIN LOSS: 0.020381297916173935
# AVERAGE VAL LOSS: 0.06545174866914749
# #################
# # EPOCH 2906
# #################
# AVERAGE TRAIN LOSS: 0.020099494606256485
# AVERAGE VAL LOSS: 0.0593862310051918
# #################
# # EPOCH 2907
# #################
# AVERAGE TRAIN LOSS: 0.01967664435505867
# AVERAGE VAL LOSS: 0.057928454130887985
# #################
# # EPOCH 2908
# #################
# AVERAGE TRAIN LOSS: 0.02525915764272213
# AVERAGE VAL LOSS: 0.06529977172613144
# #################
# # EPOCH 2909
# #################
# AVERAGE TRAIN LOSS: 0.02032683789730072
# AVERAGE VAL LOSS: 0.05646964907646179
# #################
# # EPOCH 2910
# #################
# AVERAGE TRAIN LOSS: 0.020618945360183716
# AVERAGE VAL LOSS: 0.06018417701125145
# #################
# # EPOCH 2911
# #################
# AVERAGE TRAIN LOSS: 0.018981484696269035
# AVERAGE VAL LOSS: 0.06344376504421234
# #################
# # EPOCH 2912
# #################
# AVERAGE TRAIN LOSS: 0.019907992333173752
# AVERAGE VAL LOSS: 0.06202824041247368
# #################
# # EPOCH 2913
# #################
# AVERAGE TRAIN LOSS: 0.02078445628285408
# AVERAGE VAL LOSS: 0.05827810987830162
# #################
# # EPOCH 2914
# #################
# AVERAGE TRAIN LOSS: 0.02417578548192978
# AVERAGE VAL LOSS: 0.06845496594905853
# #################
# # EPOCH 2915
# #################
# AVERAGE TRAIN LOSS: 0.02088538557291031
# AVERAGE VAL LOSS: 0.05799693986773491
# #################
# # EPOCH 2916
# #################
# AVERAGE TRAIN LOSS: 0.01967073604464531
# AVERAGE VAL LOSS: 0.059193529188632965
# #################
# # EPOCH 2917
# #################
# AVERAGE TRAIN LOSS: 0.02058526501059532
# AVERAGE VAL LOSS: 0.06304680556058884
# #################
# # EPOCH 2918
# #################
# AVERAGE TRAIN LOSS: 0.021673765033483505
# AVERAGE VAL LOSS: 0.06239968538284302
# #################
# # EPOCH 2919
# #################
# AVERAGE TRAIN LOSS: 0.02217535674571991
# AVERAGE VAL LOSS: 0.05765153840184212
# #################
# # EPOCH 2920
# #################
# AVERAGE TRAIN LOSS: 0.020028237253427505
# AVERAGE VAL LOSS: 0.06504255533218384
# #################
# # EPOCH 2921
# #################
# AVERAGE TRAIN LOSS: 0.019854556769132614
# AVERAGE VAL LOSS: 0.06418384611606598
# #################
# # EPOCH 2922
# #################
# AVERAGE TRAIN LOSS: 0.0200855303555727
# AVERAGE VAL LOSS: 0.06158420071005821
# #################
# # EPOCH 2923
# #################
# AVERAGE TRAIN LOSS: 0.01924288645386696
# AVERAGE VAL LOSS: 0.05765414237976074
# #################
# # EPOCH 2924
# #################
# AVERAGE TRAIN LOSS: 0.02063934877514839
# AVERAGE VAL LOSS: 0.06068965420126915
# #################
# # EPOCH 2925
# #################
# AVERAGE TRAIN LOSS: 0.022594977170228958
# AVERAGE VAL LOSS: 0.05597580596804619
# #################
# # EPOCH 2926
# #################
# AVERAGE TRAIN LOSS: 0.019737491384148598
# AVERAGE VAL LOSS: 0.06748246401548386
# #################
# # EPOCH 2927
# #################
# AVERAGE TRAIN LOSS: 0.020452814176678658
# AVERAGE VAL LOSS: 0.06249738484621048
# #################
# # EPOCH 2928
# #################
# AVERAGE TRAIN LOSS: 0.02013256400823593
# AVERAGE VAL LOSS: 0.06357937306165695
# #################
# # EPOCH 2929
# #################
# AVERAGE TRAIN LOSS: 0.02036968804895878
# AVERAGE VAL LOSS: 0.06031538173556328
# #################
# # EPOCH 2930
# #################
# AVERAGE TRAIN LOSS: 0.019913841038942337
# AVERAGE VAL LOSS: 0.06221788004040718
# #################
# # EPOCH 2931
# #################
# AVERAGE TRAIN LOSS: 0.019180821254849434
# AVERAGE VAL LOSS: 0.06104111671447754
# #################
# # EPOCH 2932
# #################
# AVERAGE TRAIN LOSS: 0.020842980593442917
# AVERAGE VAL LOSS: 0.06615375727415085
# #################
# # EPOCH 2933
# #################
# AVERAGE TRAIN LOSS: 0.018727745860815048
# AVERAGE VAL LOSS: 0.0591747872531414
# #################
# # EPOCH 2934
# #################
# AVERAGE TRAIN LOSS: 0.019304577261209488
# AVERAGE VAL LOSS: 0.05955949053168297
# #################
# # EPOCH 2935
# #################
# AVERAGE TRAIN LOSS: 0.019479380920529366
# AVERAGE VAL LOSS: 0.05785924941301346
# #################
# # EPOCH 2936
# #################
# AVERAGE TRAIN LOSS: 0.019343849271535873
# AVERAGE VAL LOSS: 0.061617638915777206
# #################
# # EPOCH 2937
# #################
# AVERAGE TRAIN LOSS: 0.019015241414308548
# AVERAGE VAL LOSS: 0.06281905621290207
# #################
# # EPOCH 2938
# #################
# AVERAGE TRAIN LOSS: 0.020053675398230553
# AVERAGE VAL LOSS: 0.05915501341223717
# #################
# # EPOCH 2939
# #################
# AVERAGE TRAIN LOSS: 0.019476378336548805
# AVERAGE VAL LOSS: 0.06252876669168472
# #################
# # EPOCH 2940
# #################
# AVERAGE TRAIN LOSS: 0.01978263072669506
# AVERAGE VAL LOSS: 0.060762256383895874
# #################
# # EPOCH 2941
# #################
# AVERAGE TRAIN LOSS: 0.019711459055542946
# AVERAGE VAL LOSS: 0.06016906723380089
# #################
# # EPOCH 2942
# #################
# AVERAGE TRAIN LOSS: 0.019254133105278015
# AVERAGE VAL LOSS: 0.06196790561079979
# #################
# # EPOCH 2943
# #################
# AVERAGE TRAIN LOSS: 0.01902131736278534
# AVERAGE VAL LOSS: 0.06067293509840965
# #################
# # EPOCH 2944
# #################
# AVERAGE TRAIN LOSS: 0.019810045138001442
# AVERAGE VAL LOSS: 0.05863572284579277
# #################
# # EPOCH 2945
# #################
# AVERAGE TRAIN LOSS: 0.019225087016820908
# AVERAGE VAL LOSS: 0.06160297617316246
# #################
# # EPOCH 2946
# #################
# AVERAGE TRAIN LOSS: 0.019189810380339622
# AVERAGE VAL LOSS: 0.06199755147099495
# #################
# # EPOCH 2947
# #################
# AVERAGE TRAIN LOSS: 0.0197122935205698
# AVERAGE VAL LOSS: 0.06392673403024673
# #################
# # EPOCH 2948
# #################
# AVERAGE TRAIN LOSS: 0.019076555967330933
# AVERAGE VAL LOSS: 0.06072735786437988
# #################
# # EPOCH 2949
# #################
# AVERAGE TRAIN LOSS: 0.018891260027885437
# AVERAGE VAL LOSS: 0.05995435640215874
# #################
# # EPOCH 2950
# #################
# AVERAGE TRAIN LOSS: 0.021377846598625183
# AVERAGE VAL LOSS: 0.06364832073450089
# #################
# # EPOCH 2951
# #################
# AVERAGE TRAIN LOSS: 0.0206572525203228
# AVERAGE VAL LOSS: 0.05597802624106407
# #################
# # EPOCH 2952
# #################
# AVERAGE TRAIN LOSS: 0.020017500966787338
# AVERAGE VAL LOSS: 0.06166749820113182
# #################
# # EPOCH 2953
# #################
# AVERAGE TRAIN LOSS: 0.018805379047989845
# AVERAGE VAL LOSS: 0.06424428522586823
# #################
# # EPOCH 2954
# #################
# AVERAGE TRAIN LOSS: 0.02000008150935173
# AVERAGE VAL LOSS: 0.05994940921664238
# #################
# # EPOCH 2955
# #################
# AVERAGE TRAIN LOSS: 0.018894053995609283
# AVERAGE VAL LOSS: 0.06042605638504028
# #################
# # EPOCH 2956
# #################
# AVERAGE TRAIN LOSS: 0.0195059385150671
# AVERAGE VAL LOSS: 0.06320681422948837
# #################
# # EPOCH 2957
# #################
# AVERAGE TRAIN LOSS: 0.02226758934557438
# AVERAGE VAL LOSS: 0.059362370520830154
# #################
# # EPOCH 2958
# #################
# AVERAGE TRAIN LOSS: 0.021913772448897362
# AVERAGE VAL LOSS: 0.06780699640512466
# #################
# # EPOCH 2959
# #################
# AVERAGE TRAIN LOSS: 0.020030563697218895
# AVERAGE VAL LOSS: 0.05939115956425667
# #################
# # EPOCH 2960
# #################
# AVERAGE TRAIN LOSS: 0.020856667309999466
# AVERAGE VAL LOSS: 0.06029036268591881
# #################
# # EPOCH 2961
# #################
# AVERAGE TRAIN LOSS: 0.019333254545927048
# AVERAGE VAL LOSS: 0.063191257417202
# #################
# # EPOCH 2962
# #################
# AVERAGE TRAIN LOSS: 0.01969055086374283
# AVERAGE VAL LOSS: 0.06201814487576485
# #################
# # EPOCH 2963
# #################
# AVERAGE TRAIN LOSS: 0.02059914730489254
# AVERAGE VAL LOSS: 0.05743459612131119
# #################
# # EPOCH 2964
# #################
# AVERAGE TRAIN LOSS: 0.020358091220259666
# AVERAGE VAL LOSS: 0.06213134527206421
# #################
# # EPOCH 2965
# #################
# AVERAGE TRAIN LOSS: 0.019382668659090996
# AVERAGE VAL LOSS: 0.0585998073220253
# #################
# # EPOCH 2966
# #################
# AVERAGE TRAIN LOSS: 0.018992815166711807
# AVERAGE VAL LOSS: 0.0601029172539711
# #################
# # EPOCH 2967
# #################
# AVERAGE TRAIN LOSS: 0.01902184821665287
# AVERAGE VAL LOSS: 0.06075691804289818
# #################
# # EPOCH 2968
# #################
# AVERAGE TRAIN LOSS: 0.021886209025979042
# AVERAGE VAL LOSS: 0.06573760509490967
# #################
# # EPOCH 2969
# #################
# AVERAGE TRAIN LOSS: 0.02551763318479061
# AVERAGE VAL LOSS: 0.05670475959777832
# #################
# # EPOCH 2970
# #################
# AVERAGE TRAIN LOSS: 0.020799022167921066
# AVERAGE VAL LOSS: 0.06431440263986588
# #################
# # EPOCH 2971
# #################
# AVERAGE TRAIN LOSS: 0.020360354334115982
# AVERAGE VAL LOSS: 0.0674348846077919
# #################
# # EPOCH 2972
# #################
# AVERAGE TRAIN LOSS: 0.02063993737101555
# AVERAGE VAL LOSS: 0.059050142765045166
# #################
# # EPOCH 2973
# #################
# AVERAGE TRAIN LOSS: 0.01964542269706726
# AVERAGE VAL LOSS: 0.06093275174498558
# #################
# # EPOCH 2974
# #################
# AVERAGE TRAIN LOSS: 0.019194144755601883
# AVERAGE VAL LOSS: 0.06309818476438522
# #################
# # EPOCH 2975
# #################
# AVERAGE TRAIN LOSS: 0.022867731750011444
# AVERAGE VAL LOSS: 0.06943313032388687
# #################
# # EPOCH 2976
# #################
# AVERAGE TRAIN LOSS: 0.018916428089141846
# AVERAGE VAL LOSS: 0.056024473160505295
# #################
# # EPOCH 2977
# #################
# AVERAGE TRAIN LOSS: 0.021530523896217346
# AVERAGE VAL LOSS: 0.05827238783240318
# #################
# # EPOCH 2978
# #################
# AVERAGE TRAIN LOSS: 0.019370734691619873
# AVERAGE VAL LOSS: 0.06018519029021263
# #################
# # EPOCH 2979
# #################
# AVERAGE TRAIN LOSS: 0.01907901093363762
# AVERAGE VAL LOSS: 0.061748530715703964
# #################
# # EPOCH 2980
# #################
# AVERAGE TRAIN LOSS: 0.019433297216892242
# AVERAGE VAL LOSS: 0.05984063073992729
# #################
# # EPOCH 2981
# #################
# AVERAGE TRAIN LOSS: 0.01882953569293022
# AVERAGE VAL LOSS: 0.06307917833328247
# #################
# # EPOCH 2982
# #################
# AVERAGE TRAIN LOSS: 0.019777214154601097
# AVERAGE VAL LOSS: 0.06217334792017937
# #################
# # EPOCH 2983
# #################
# AVERAGE TRAIN LOSS: 0.021601567044854164
# AVERAGE VAL LOSS: 0.05786534771323204
# #################
# # EPOCH 2984
# #################
# AVERAGE TRAIN LOSS: 0.019110433757305145
# AVERAGE VAL LOSS: 0.06325598061084747
# #################
# # EPOCH 2985
# #################
# AVERAGE TRAIN LOSS: 0.021300658583641052
# AVERAGE VAL LOSS: 0.06762418895959854
# #################
# # EPOCH 2986
# #################
# AVERAGE TRAIN LOSS: 0.019324976950883865
# AVERAGE VAL LOSS: 0.05911370739340782
# #################
# # EPOCH 2987
# #################
# AVERAGE TRAIN LOSS: 0.020922768861055374
# AVERAGE VAL LOSS: 0.05773095041513443
# #################
# # EPOCH 2988
# #################
# AVERAGE TRAIN LOSS: 0.019579144194722176
# AVERAGE VAL LOSS: 0.06410550326108932
# #################
# # EPOCH 2989
# #################
# AVERAGE TRAIN LOSS: 0.020107055082917213
# AVERAGE VAL LOSS: 0.06185179576277733
# #################
# # EPOCH 2990
# #################
# AVERAGE TRAIN LOSS: 0.019488852471113205
# AVERAGE VAL LOSS: 0.06147858127951622
# #################
# # EPOCH 2991
# #################
# AVERAGE TRAIN LOSS: 0.019377434626221657
# AVERAGE VAL LOSS: 0.06311149895191193
# #################
# # EPOCH 2992
# #################
# AVERAGE TRAIN LOSS: 0.019457688555121422
# AVERAGE VAL LOSS: 0.059495922178030014
# #################
# # EPOCH 2993
# #################
# AVERAGE TRAIN LOSS: 0.02027187868952751
# AVERAGE VAL LOSS: 0.058856215327978134
# #################
# # EPOCH 2994
# #################
# AVERAGE TRAIN LOSS: 0.019249742850661278
# AVERAGE VAL LOSS: 0.06308954209089279
# #################
# # EPOCH 2995
# #################
# AVERAGE TRAIN LOSS: 0.01943192444741726
# AVERAGE VAL LOSS: 0.06145713850855827
# #################
# # EPOCH 2996
# #################
# AVERAGE TRAIN LOSS: 0.019601808860898018
# AVERAGE VAL LOSS: 0.05856883525848389
# #################
# # EPOCH 2997
# #################
# AVERAGE TRAIN LOSS: 0.019368760287761688
# AVERAGE VAL LOSS: 0.06191091611981392
# #################
# # EPOCH 2998
# #################
# AVERAGE TRAIN LOSS: 0.02440335787832737
# AVERAGE VAL LOSS: 0.07080607861280441
# #################
# # EPOCH 2999
# #################
# AVERAGE TRAIN LOSS: 0.02154185250401497
# AVERAGE VAL LOSS: 0.058688051998615265

# %%
#could implement a early stopping, stopping the training if the loss doean't imporve after a tot number of epochs.

# %% [markdown]
# ### Plot losses
#
# Additional tool for visualization: tensorboard

# %%
# Plot losses
plt.figure(figsize=(12,8))
plt.semilogy(train_loss_log, label='Train loss')
plt.semilogy(val_loss_log, label='Validation loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.grid()
plt.legend()
plt.show()

#Network is learninf fast at the beginning, we do start to overfit after 200 epoches
#we could have stop at 500 epochs, going foward the validation loss increases.

# %% [markdown]
# # Network analysis

# %% [markdown]
# ## Network output

# %%
# Input vector
x_vec = torch.linspace(0,1,1000)
x_vec = x_vec.to(device)
x_vec = x_vec.unsqueeze(-1)  # Adding a dimension to the input vector
print(f"Input shape: {x_vec.shape}")

# Network output
# eval() acts as switch for some specific layers/parts of the model that behave
# differently during training and inference (eval) time. For example, Dropout 
# BatchNorm etc. 
net.eval()
with torch.no_grad(): # turn off gradients computation
    y_vec = net(x_vec)
print(f"Output shape: {y_vec.shape}")

# Expected output
beta_true = [-1.45, 1.12, 2.3]
true_model = poly_model(x_vec.cpu().numpy(), beta_true).squeeze()
# Out:
# Input shape: torch.Size([1000, 1])
# Output shape: torch.Size([1000, 1])

# %%
# Convert x_vec and y_vec to numpy one dimensional arrays
x_vec = x_vec.squeeze().cpu().numpy()
y_vec = y_vec.squeeze().cpu().numpy()

# Plot output
plt.figure(figsize=(12,8))
plt.plot(x_vec, y_vec, label='Network output')
plt.plot(x_vec, true_model, label='True model')
plt.xlabel('x')
plt.ylabel('y')
plt.grid()
plt.legend()
plt.show()

# %%
#Our model is going really well, a little bit worse for smaller values. We however have a problem if we try to predict outside the range

# %% [markdown]
# ### What if we predict outside the range?

# %%
# Input vector
x_vec = torch.linspace(-5,5,1000)
x_vec = x_vec.to(device)
x_vec = x_vec.unsqueeze(-1)  # Adding a dimension to the input vector
print(f"Input shape: {x_vec.shape}")

# Network output
net.eval()
with torch.no_grad():
    y_vec = net(x_vec)
print(f"Output shape: {y_vec.shape}")

# Expected output
beta_true = [-1.45, 1.12, 2.3]
true_model = poly_model(x_vec.cpu().numpy(), beta_true).squeeze()

# Convert x_vec and y_vec to numpy one dimensional arrays
x_vec = x_vec.squeeze().cpu().numpy()
y_vec = y_vec.squeeze().cpu().numpy()

# Plot output
plt.figure(figsize=(12,8))
plt.plot(x_vec, y_vec, label='Network output')
plt.plot(x_vec, true_model, label='True model')
plt.xlabel('x')
plt.ylabel('y')
plt.grid()
plt.legend()
plt.show()
# Out:
# Input shape: torch.Size([1000, 1])
# Output shape: torch.Size([1000, 1])

# %%
#Outside the range, where we don't have any training point, we don't fit well our model, we should give some sample to the network.

# %% [markdown]
# ### What if we try different activation functions? (e.g., ReLU for nonlinearities)
#
# ### Homework (optional): add some regularization to fight overfitting (e.g., dropout, weight decay,...)

# %%
#TO DO TO DO TO DO TO DO TO DO TO DO

# %% [markdown]
# ## Access network parameters

# %%
# First hidden layer
h1_w = net.fc1.weight.data.cpu().numpy()
h1_b = net.fc1.bias.data.cpu().numpy()

# Second hidden layer
h2_w = net.fc2.weight.data.cpu().numpy()
h2_b = net.fc2.bias.data.cpu().numpy()

# Output layer
out_w = net.out.weight.data.cpu().numpy()
out_b = net.out.bias.data.cpu().numpy()

# %% [markdown]
# ## Weights histogram

# %%
# Weights histogram
fig, axs = plt.subplots(3, 1, figsize=(12,8))
axs[0].hist(h1_w.flatten(), 50)
axs[0].set_title('First hidden layer weights')
axs[1].hist(h2_w.flatten(), 50)
axs[1].set_title('Second hidden layer weights')
axs[2].hist(out_w.flatten(), 50)
axs[2].set_title('Output layer weights')
[ax.grid() for ax in axs]
plt.tight_layout()
plt.show()

# %% [markdown]
# #### Homework (simple): compare the histogram before and after the training

# %%
# TO DO TO DO TO DO TO DO

# %% [markdown]
# ## Save network parameters

# %% [markdown]
# ### Save network

# %%
### Save network parameters
### Save the network state
# The state dictionary includes all the parameters of the network
net_state_dict = net.state_dict()
print(net_state_dict.keys())
# Save the state dict to a file
torch.save(net_state_dict, 'net_parameters.torch')
# Out:
# odict_keys(['fc1.weight', 'fc1.bias', 'fc2.weight', 'fc2.bias', 'out.weight', 'out.bias'])

# %% [markdown]
# ### Load network

# %%
### Reload the network state
# First initialize the network (if not already done)
# IMPORTANT: you need to know the model definition!!
net = Net(Ni, Nh1, Nh2, No) 
# Load the state dict previously saved
net_state_dict = torch.load('net_parameters.torch')
# Update the network parameters
net.load_state_dict(net_state_dict)
# Out:
# Network initialized
# <All keys matched successfully>

# %% [markdown]
# ## Save optimizer state
# Also the optimizer has its internal state!
#
# You need to save both the network and the optimizer states if you want to continue your training.
#
# If you are sure you have finished your training you can just save the network.

# %%
### Save the optimizer state
#print(optimizer.state_dict()['state'])
torch.save(optimizer.state_dict(), 'optimizer_state.torch')

### Reload the optimizer state
optimizer = optim.Adam(net.parameters(), lr=0.001)
opt_state_dict = torch.load('optimizer_state.torch')
optimizer.load_state_dict(opt_state_dict)

# %% [markdown]
# ## Analyze activations

# %%
# First naive way: simply change the network definition to return an additional output

# More advanced strategy: using hooks

def get_activation(layer, input, output):
    global activation
    activation = torch.sigmoid(output)

### Register hook  
hook_handle = net.fc2.register_forward_hook(get_activation)

### Analyze activations
net = net.to(device)
net.eval()
with torch.no_grad():
    x1 = torch.tensor([0.1]).float().to(device)
    y1 = net(x1)
    z1 = activation
    x2 = torch.tensor([0.9]).float().to(device)
    y2 = net(x2)
    z2 = activation
    x3 = torch.tensor([2.5]).float().to(device)
    y3 = net(x3)
    z3 = activation

### Remove hook
hook_handle.remove()

### Plot activations
fig, axs = plt.subplots(3, 1, figsize=(12,6))
axs[0].stem(z1.cpu().numpy(), use_line_collection=True)
axs[0].set_title('Last layer activations for input x=%.2f' % x1)
axs[1].stem(z2.cpu().numpy(), use_line_collection=True)
axs[1].set_title('Last layer activations for input x=%.2f' % x2)
axs[2].stem(z3.cpu().numpy(), use_line_collection=True)
axs[2].set_title('Last layer activations for input x=%.2f' % x3)
plt.tight_layout()
plt.show()

# %% [markdown]
# # Exercise - Classification model

# %% [markdown]
# **HINTS**
# - Choose a loss function that is suitable for the specific problem, a binary classification in this case. If you keep a single linear output you can use a BCEWithLogitsLoss, which is more numerically stable than manually using a sigmoid output activation (more info here: https://pytorch.org/docs/stable/generated/torch.nn.BCEWithLogitsLoss.html ).
# - The network now has 2 inputs. A batched input should have a shape $\text{batch_size} \times 2$.
# - The dataset should be adapted accordingly. Also consider to increase the batch size.
# - Explore different optimizers, trying to understand the differences and their parameters (https://pytorch.org/docs/stable/optim.html ).
# - Try to increase the complexity of the network, and at the same time to introduce some regularization with dropout layers and/or weight decay (which is equivalent to an L2 regularization, typically implemented by the optimizer).
# - Experiment with different hyper-parameters trying to minimize the VALIDATION LOSS. Once you are happy with the result, try the final test with the TEST dataset.

# %% [markdown]
# ## Data generation

# %%
import itertools

np.random.seed(123)

def bidimensional_model(x1, x2):
    a = 1
    b = 1
    cx1 = 0
    cx2 = 0
    out = (x1 - cx1)**2 / a**2 + (x2 - cx2)**2 / b **2 < 1
    a = 2
    b = 2
    cx1 = 5
    cx2 = 5
    out |= (x1 - cx1)**2 / a**2 + (x2 - cx2)**2 / b **2 < 1
    a = 1
    b = 2
    cx1 = -2.5
    cx2 = 5
    out |= (x1 - cx1)**2 / a**2 + (x2 - cx2)**2 / b **2 < 1
    a = 3
    b = 1
    cx1 = -6
    cx2 = -2.5
    out |= (x1 - cx1)**2 / a**2 + (x2 - cx2)**2 / b **2 < 1
    a = 2
    b = 4
    cx1 = -7.5
    cx2 = -5
    out |= (x1 - cx1)**2 / a**2 + (x2 - cx2)**2 / b **2 < 1
    a = 6
    b = 1
    cx1 = -7.5
    cx2 = 5
    out |= (x1 - cx1)**2 / a**2 + (x2 - cx2)**2 / b **2 < 1
    a = 4
    b = 4
    cx1 = 7.5
    cx2 = -7.5
    out |= (x1 - cx1)**2 / a**2 + (x2 - cx2)**2 / b **2 < 1
    a = 3
    b = 2
    cx1 = -1
    cx2 = -6
    out |= (x1 - cx1)**2 / a**2 + (x2 - cx2)**2 / b **2 < 1
    a = 2
    b = 5
    cx1 = 1
    cx2 = 6
    out |= (x1 - cx1)**2 / a**2 + (x2 - cx2)**2 / b **2 < 1
    a = 2
    b = 2
    cx1 = 6
    cx2 = 0
    out |= (x1 - cx1)**2 / a**2 + (x2 - cx2)**2 / b **2 < 1
    return out.astype(int)

### PLOT MODEL
# Input grid
x1 = np.linspace(-10, 10, 400)
x2 = np.linspace(-10, 10, 400)
x_prod = [x for x in itertools.product(x1, x2)]
x1 = np.array([x[0] for x in x_prod])
x2 = np.array([x[1] for x in x_prod])
# Evaluate out
y = bidimensional_model(x1, x2)
# Scatter plot
fig, ax = plt.subplots(figsize=(12,8))
colors = np.array(['C0', 'C1'])
ax.scatter(x1, x2, c=colors[y], s=10, marker='o')
ax.set_xlabel('x1')
ax.set_ylabel('x2')
fig.show()

# %% [markdown]
# ### Training points

# %%
import pandas as pd

### Train data
num_points = 1000
x1 = np.random.uniform(-10, 10, num_points)
x2 = np.random.uniform(-10, 10, num_points)
y = bidimensional_model(x1, x2)
train_df = pd.DataFrame({'x1': x1, 'x2': x2, 'y': y})
train_df.to_csv('classifier_train_data.csv', index=False)

fig, ax = plt.subplots(figsize=(12,8))
ax.scatter(x1, x2, c=colors[y], s=10, marker='o')
ax.set_xlabel('x1')
ax.set_ylabel('x2')
ax.set_title('Training points')
fig.show()

# %% [markdown]
# ### Validation points

# %% [markdown]
# In this case: we generate validation points.
# Usually: validation points are randomly selected from the training points (~20% of training data).

# %%
### Validation data
num_points = 200
x1 = np.random.uniform(-10, 10, num_points)
x2 = np.random.uniform(-10, 10, num_points)
y = bidimensional_model(x1, x2)
val_df = pd.DataFrame({'x1': x1, 'x2': x2, 'y': y})
val_df.to_csv('classifier_val_data.csv', index=False)

fig, ax = plt.subplots(figsize=(12,8))
ax.scatter(x1, x2, c=colors[y], s=10, marker='o')
ax.set_xlabel('x1')
ax.set_ylabel('x2')
ax.set_title('Validation points')
fig.show()

# %% [markdown]
# ### Test points

# %%
### Test data
num_points = 400
x1 = np.random.uniform(-10, 10, num_points)
x2 = np.random.uniform(-10, 10, num_points)
y = bidimensional_model(x1, x2)
val_df = pd.DataFrame({'x1': x1, 'x2': x2, 'y': y})
val_df.to_csv('classifier_test_data.csv', index=False)

fig, ax = plt.subplots(figsize=(12,8))
ax.scatter(x1, x2, c=colors[y], s=10, marker='o')
ax.set_xlabel('x1')
ax.set_ylabel('x2')
ax.set_title('Test points')
fig.show()

# %% [markdown]
# ## Dataset and Dataloader

# %% [markdown]
# Define the dataset

# %%
class ClassifierDataset(Dataset):

    def __init__(self, csv_file, transform=None):
        """
        Args:
            csv_file (string): Path to the csv file.
            transform (callable, optional): Optional transform to be applied
                on a sample.
        """
        self.transform = transform
        # Read the file and store the content in a pandas DataFrame
        self.df = pd.read_csv(csv_file)

    def __len__(self):
        # The length of the dataset is simply the length of the self.data list
        return len(self.df)

    def __getitem__(self, idx):
        # Our sample is the row at index idx of the dataframe
        row = self.df.iloc[idx]
        # There are 2 inputs this time
        sample = ([row.x1, row.x2], row.y)
        if self.transform:
            sample = self.transform(sample)
        return sample

# %% [markdown]
# Define the transformations

# %%
class ToTensor(object):
    """Convert sample to Tensors."""

    def __call__(self, sample):
        x, y = sample
        return (torch.Tensor(x).float(),
                torch.Tensor([y]).float())

# %% [markdown]
# Initialize the datasets

# %%
composed_transform = transforms.Compose([ToTensor()])

train_dataset = ClassifierDataset('classifier_train_data.csv', transform=composed_transform)
val_dataset   = ClassifierDataset('classifier_val_data.csv', transform=composed_transform)
test_dataset  = ClassifierDataset('classifier_test_data.csv', transform=composed_transform)

# %% [markdown]
# Define the dataloaders

# %%
train_dataloader = DataLoader(train_dataset, batch_size=200, shuffle=True, num_workers=0)
val_dataloader   = DataLoader(val_dataset,   batch_size=len(val_dataset), shuffle=False, num_workers=0)
test_dataloader  = DataLoader(test_dataset,  batch_size=len(test_dataset), shuffle=False, num_workers=0)

# %% [markdown]
# ## Network definition

# %%
class Net(nn.Module):
    
    def __init__(self, Ni, Nh1, Nh2, No):
        """
        Ni - Input size
        Nh1 - Neurons in the 1st hidden layer
        Nh2 - Neurons in the 2nd hidden layer
        No - Output size
        """
        super().__init__()
        
        print('Network initialized')
        self.fc1 = nn.Linear(in_features=Ni, out_features=Nh1)
        self.fc2 = nn.Linear(in_features=Nh1, out_features=Nh2)
        self.out = nn.Linear(in_features=Nh2, out_features=No)
        self.act = nn.Sigmoid()
        
    def forward(self, x, additional_out=False):
        x = self.act(self.fc1(x))
        x = self.act(self.fc2(x))
        x = self.out(x)
        return x

# %% [markdown]
# ## Training loop

# %%
# Initialize the network
torch.manual_seed(0)
Ni = 2
Nh1 = 128
Nh2 = 256
No = 1 # TODO: understand why we are doing this (see comments later)
# Homework: change the code in order to set No = 2

net = Net(Ni, Nh1, Nh2, No)
net.to(device)

# Define the loss function
loss_fn = # TODO: use a proper classification loss

# Define the optimizer
optimizer = optim.Adam(net.parameters(), lr=1e-2)
# Out:
#   File "<ipython-input-38-c182a5808689>", line 13
#     loss_fn = # TODO: use a proper classification loss
#                                                       ^
# SyntaxError: invalid syntax

# %%
### TRAINING LOOP
num_epochs = 600
train_loss_log = []
val_loss_log = []
for epoch_num in range(num_epochs):
    print('#################')
    print(f'# EPOCH {epoch_num}')
    print('#################')

    ### TRAIN
    train_loss= []
    net.train() # Training mode (e.g. enable dropout)
    for sample_batched in train_dataloader:
        # Move data to device
        x_batch = sample_batched[0].to(device)
        label_batch = sample_batched[1].to(device)

        # Forward pass
        out = net(x_batch)

        # Compute loss
        loss = loss_fn(out, label_batch)

        # Backpropagation
        net.zero_grad()
        loss.backward()

        # Update the weights
        optimizer.step()

        # Save train loss for this batch
        loss_batch = loss.detach().cpu().numpy()
        train_loss.append(loss_batch)

    # Save average train loss
    train_loss = np.mean(train_loss)
    print(f"AVERAGE TRAIN LOSS: {train_loss}")
    train_loss_log.append(train_loss)

    ### VALIDATION
    val_loss= []
    net.eval() # Evaluation mode (e.g. disable dropout)
    with torch.no_grad(): # Disable gradient tracking
        for sample_batched in val_dataloader:
            # Move data to device
            x_batch = sample_batched[0].to(device)
            label_batch = sample_batched[1].to(device)

            # Forward pass
            out = net(x_batch)

            # Compute loss
            loss = loss_fn(out, label_batch)

            # Save val loss for this batch
            loss_batch = loss.detach().cpu().numpy()
            val_loss.append(loss_batch)

        # Save average validation loss
        val_loss = np.mean(val_loss)
        print(f"AVERAGE VAL LOSS: {np.mean(val_loss)}")
        val_loss_log.append(val_loss)

# %%
# Plot losses
plt.figure(figsize=(12,8))
plt.semilogy(train_loss_log, label='Train loss')
plt.semilogy(val_loss_log, label='Validation loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.grid()
plt.legend()
plt.show()

# %% [markdown]
# ## Final test

# %% [markdown]
# Iterate the dataloader a single time and save all the outputs (in case you have multiple batches)

# %%
all_inputs = []
all_outputs = []
all_labels = []
net.eval() # Evaluation mode (e.g. disable dropout)
with torch.no_grad(): # Disable gradient tracking
    for sample_batched in test_dataloader:
        # Move data to device
        x_batch = sample_batched[0].to(device)
        label_batch = sample_batched[1].to(device)
        # Forward pass
        out = net(x_batch)
        # Save outputs and labels
        all_inputs.append(x_batch)
        all_outputs.append(out)
        all_labels.append(label_batch)
# Concatenate all the outputs and labels in a single tensor
all_inputs  = torch.cat(all_inputs)
all_outputs = torch.cat(all_outputs)
all_labels  = torch.cat(all_labels)

test_loss = loss_fn(all_outputs, all_labels)
print(f"AVERAGE TEST LOSS: {test_loss}")

# %% [markdown]
# In this case the network has a linear output (for a better stability of the loss function).
# To have probability estimates you can apply a sigmoid to the network output.
#
# Since we just need the most probable class and we have a single output, we can consider the sign of the linear output. Negative output means that the class 0 is the most probable (probability < 50%), otherwise class 1 (probability > 50%).
#
# Essentially this network estimates the probability of the input sample to be of class 1.
#
# > **NOTE**
# >
# > You can (and should, for practice) redefine the problem by defining a network with more than one output, each of them corresponding to a specific class (2 in this case). Since the two classes are mutually exclusive, the loss function should be a CrossEntropyLoss (softmax activation). In a multi-class scenario, a BCE loss is suitable when the classes are NOT mutually exclusive.

# %% [markdown]
# ---
#
#
# Get the most probable class inferred by the network

# %%
# Get the most probable class inferred by the network
all_output_classes = torch.zeros(all_outputs.shape).to(device)
all_output_classes[all_outputs > 0] = # TODO: what's going on here?

# %% [markdown]
# Evaluate the test accuracy

# %%
tot_correct_out = (all_output_classes == all_labels).sum()
test_accuracy = 100 * tot_correct_out / len(all_labels)
print(f"TEST ACCURACY: {test_accuracy:.2f}%")

# %% [markdown]
# Plot the results

# %%
### Plot
x1 = all_inputs.squeeze().cpu().numpy()[:, 0]
x2 = all_inputs.squeeze().cpu().numpy()[:, 1]
y_true = all_labels.squeeze().cpu().numpy()
y_pred = all_output_classes.squeeze().cpu().numpy()

fig, ax = plt.subplots(figsize=(12,8))
# Plot predictions
ax.scatter(x1, x2, c=colors[y_pred.astype(np.uint8)], s=10, marker='o')
ax.set_xlabel('x1')
ax.set_ylabel('x2')
ax.set_title('Network Predictions')
# Mark wrong outputs
error_mask = y_pred != y_true
ax.scatter(x1[error_mask], x2[error_mask], color='red', s=100, marker='x', label='MISCLASSIFIED SAMPLES')
plt.legend()
fig.show()

# %% [markdown]
# # High-level and Lightweight PyTorch wrapper: PyTorch Lightning

# %% [markdown]
# Lightning forces the following structure to your code which makes it reusable and shareable:
#
# Research code (the LightningModule).
# Engineering code (you delete, and is handled by the Trainer).
# Non-essential research code (logging, etc... this goes in Callbacks).
# Data (use PyTorch DataLoaders or organize them into a LightningDataModule).
# Once you do this, you can train on multiple-GPUs, TPUs, CPUs and even in 16-bit precision without changing your code!

# %%
! pip install pytorch-lightning

import os
import torch
from torch import nn
import torch.nn.functional as F
from torchvision import transforms
from torchvision.datasets import MNIST
from torch.utils.data import DataLoader, random_split
import pytorch_lightning as pl

# %%
# Define a LightningModule (nn.Module subclass)
# A LightningModule defines a full system (ie: a GAN, autoencoder, BERT or a simple Image Classifier).
class LitNet(pl.LightningModule):
    def __init__(self, Ni, Nh1, Nh2, No):
        """
        Ni - Input size
        Nh1 - Neurons in the 1st hidden layer
        Nh2 - Neurons in the 2nd hidden layer
        No - Output size
        """
        super().__init__()
        
        print('Network initialized')
        self.net = nn.Sequential(nn.Linear(in_features=Ni, out_features=Nh1), 
                       nn.Sigmoid(), 
                       nn.Linear(in_features=Nh1, out_features=Nh2),
                       nn.Sigmoid(),
                       nn.Linear(in_features=Nh2, out_features=No))
        self.val_loss = []
        self.train_loss = []

    # Forward step defines how the LightningModule behaves during inference/prediction.
    def forward(self, x, additional_out=False):
        return self.net(x)

    # Training_step defines the training loop. 
    def training_step(self, batch, batch_idx=None):
        # training_step defines the train loop. It is independent of forward
        x_batch = batch[0]
        label_batch = batch[1]
        out = self.net(x_batch)
        loss = F.binary_cross_entropy_with_logits(out, label_batch)
        self.train_loss.append(loss)
        self.log("val_loss", loss.item())
        return loss

    def validation_step(self, batch, batch_idx=None):
        # training_step defines the train loop. It is independent of forward
        x_batch = batch[0]
        label_batch = batch[1]
        out = self.net(x_batch)
        loss = F.binary_cross_entropy_with_logits(out, label_batch)
        self.val_loss.append(loss.item())

    def configure_optimizers(self):
        optimizer = optim.Adam(self.net.parameters(), lr=1e-2)
        return optimizer

# %%
# TRAIN!
batch_size = 200
train_dataloader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True, num_workers=0)
val_dataloader   = DataLoader(val_dataset,   batch_size=len(val_dataset), shuffle=False, num_workers=0)
test_dataloader  = DataLoader(test_dataset,  batch_size=len(test_dataset), shuffle=False, num_workers=0)

trainer = pl.Trainer(gpus=1, max_epochs=20, val_check_interval=1)
litnet = LitNet(Ni, Nh1, Nh2, No)
trainer.fit(litnet, train_dataloader, val_dataloader)

# %%
# Plot losses
plt.figure(figsize=(12,8))
plt.semilogy(litnet.train_loss, label='Train loss')
plt.semilogy(litnet.val_loss, label='Validation loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.grid()
plt.legend()
plt.show()

# %% [markdown]
# # (Optional) Automatic Hyper-parameters Tuning: Optuna

# %% [markdown]
# Optuna is an automatic hyperparameter optimization software framework.
#
# - Lightweight, versatile, and platform agnostic architecture
# - Pythonic search spaces
# - Efficient optimization algorithms
# - Easy parallelization
# - Quick visualization
#
#
# Definitions:
#
# - Study: optimization based on an objective function
# - Trial: a single execution of the objective function
#
# The goal of a study is to find out the optimal set of hyperparameter values (e.g., classifier and svm_c) through multiple trials (e.g., n_trials=100). Optuna is a framework designed for the automation and the acceleration of the optimization studies.
#
# Optuna works with PyTorch, but also with Tensorflow, Keras and PyTorch Lightning! (and many others)

# %%
! pip install optuna

# %%
# Before we used: 
# Nh1 = 128
# Nh2 = 256

import optuna
from optuna.integration import PyTorchLightningPruningCallback

def objective(trial):

    # We optimize the number of hidden units in each layer.
    output_dims = [
        trial.suggest_int("n_units_l{}".format(i), 64, 256, log=True) for i in range(2)
    ]

    model = LitNet(Ni, output_dims[0], output_dims[1], No)

    trainer = pl.Trainer(gpus=1, max_epochs=20, val_check_interval=1, log_every_n_steps=1)
    hyperparameters = dict(output_dims=output_dims)
    trainer.logger.log_hyperparams(hyperparameters)
    trainer.fit(model, train_dataloader, val_dataloader)

    return trainer.callback_metrics["val_loss"].item()

pruner: optuna.pruners.BasePruner = optuna.pruners.NopPruner()
# print(pruner) <optuna.pruners._nop.NopPruner object at 0x7f4c2466ed50>
# print(type(pruner)) <class 'optuna.pruners._nop.NopPruner'>

study = optuna.create_study(study_name="myfirstoptimizationstudy", direction="minimize", pruner=pruner)
study.optimize(objective, n_trials=3, timeout=300)

print("Number of finished trials: {}".format(len(study.trials)))

print("Best trial:")
trial = study.best_trial

print("  Value: {}".format(trial.value))

print("  Params: ")
for key, value in trial.params.items():
    print("    {}: {}".format(key, value))

# %% [markdown]
# # Homework
#
# Try tuning other hyper-parameters, such as the learning rate.
